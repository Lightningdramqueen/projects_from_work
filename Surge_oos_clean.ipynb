# %% [markdown]
# # [Дизайн теста](https://wiki.sbmt.io/display/ANLT/%5BDRAFT%5D+AB-surge+block+coefficient+OOS)

# %% [markdown]
# # Contents

# %% [markdown]
# * [Импорты](#Импорты)
# * [Функции](#Функции)
# * [Константы](#Константы)
# * [Метрики](#Метрики)
#   * [Отмены/замены](#Отмены/замены)
#     * [Исходная логика](#Исходная_логика)
#     * [По-юзерная логика](#По-юзерная_логика)
#   * [Время сборки](#Время_сборки)
#     * [Исходная логика](#Исходная__логика)
#     * [По-юзерная логика](#По-юзерная__логика)
#   * [AOV](#AOV)
#   * [AOV первичный](#AOV_первичный)
#   * [Retention (?)](#Retention)
# * [MDE](#MDE)
#   * [Data collection](#Data_collection)
#       * [Отмены/замены](#Отмены/замены_load)
#       * [Время сборки](#Время_сборки_load)
#   * [Data preprocessing](#Data_preprocessing)
#       * [Отмены/замены](#Отмены/замены_prep)
#       * [Время сборки](#Время_сборки_prep)
#       * [Итог](#Итог)
#   * [MDE estimation](#MDE_estimation)
# * [AA & AB](#AA&AB)

# %% [markdown]
# # Импорты

# %%
import pandas as pd
import numpy as np
import datetime as dt

from matplotlib import pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
sns.set(rc={'figure.figsize':(15, 5)})

import sys
import os
import warnings

from scipy import stats as st
from scipy.stats import ttest_ind
import statsmodels.api as sm
import statsmodels.stats.api as sms
from statsmodels.stats.power import tt_ind_solve_power 

sys.path.append('/home/jovyan')
from connectors import read_sql_query
from tqdm import tqdm 


pd.set_option('display.max_columns', None)

# %%
warnings.filterwarnings("ignore")

# %%
# !pip install tabulate
# Out:
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.9/site-packages (0.9.0)

# %%
import tabulate

# %% [markdown]
# # Функции

# %%
def deltamethod(x, y, independent = False, bc = False):
    n = len(x)
    mux = np.mean(x)
    muy = np.mean(y)
    
    v11 = np.var(y,ddof=1)
    v22 = np.var(x,ddof=1)
    
    if independent == True:
        v12 = 0
    else: 
        v12 = np.cov(x,y)[0][1]
    
    est = muy / mux
    
    if bc == True:
        est = est + muy/mux**3*v22/n - 1/mux**2*v12/n
    sd = (v11 / mux**2) - (2 * muy / mux**3 * v12) + (muy**2 / mux**4 * v22)
    sd = np.sqrt(sd)
    return est, sd

# %%
def calculate_pvalue(test, control, metric, group_id, df, metric_type='proportion'):
        if metric_type == 'average' or metric_type == 'ratio':
            equal_var = False
        else:
            equal_var = True

        if metric_type == 'ratio':
            c_num_values = df[df[group_id] == control][metric[0]].values
            c_denom_values = df[df[group_id] == control][metric[1]].values
            
            t_num_values = df[df[group_id] == test][metric[0]].values
            t_denom_values = df[df[group_id] == test][metric[1]].values
                       
            control_mean = c_num_values.sum() / c_denom_values.sum()
            test_mean = t_num_values.sum() / t_denom_values.sum()

            c_values = c_num_values - c_denom_values * control_mean
            t_values = t_num_values - t_denom_values * control_mean
        else:
            c_values = df[df[group_id] == control][metric].values
            t_values = df[df[group_id] == test][metric].values
            
            control_mean = c_values.mean()
            test_mean = t_values.mean()

        return ttest_ind(c_values, t_values, equal_var=equal_var).pvalue, control_mean, test_mean

# %% [markdown]
# # Константы

# %%
end_date = dt.date.today()-dt.timedelta(days=1)

# %%
platforms = ["android","web"]
lengths = [2,3,4] #weeks
traffic_proportions = [0.125, 0.25, 0.5, 0.75, 1]
thresholds = [0.05, 0.01]

# %%
oos_stores = \
read_sql_query("""
select * from sandbox.stores_with_out_of_stock_model
""").store_id.tolist()

# %%
oos_stores_df = read_sql_query("""
select * from sandbox.stores_with_out_of_stock_model
""")

# %%
oos_stores_df.to_excel('oos_stores.xlsx',index=False)

# %%
len(oos_stores)
# Out:
# 17783

# %%
oos_stores[:10]
# Out:
# [33127, 14191, 14195, 14202, 14203, 14204, 14205, 14209, 14212, 14214]

# %% [markdown]
# # Фильтрующее

# %% [markdown]
# event_filter = f"event = 'Shop Selected' and store_id IN {tuple(map(int,oos_stores))}"

# %%
event_filter = f"event IN ('Category Viewed', 'Search Results Viewed') and store_id IN {tuple(map(int,oos_stores))}"

# %%
sources_new_app = (
    "Order Completed",
    "Landing Viewed",
    "Product Added",
    "Login",
    "Shop Selected",
    "Address Change Initiated",
    "Product Viewed",
    "Search Results Viewed",
    "Category Viewed",
    "Shop Selection Started",
    "Pickup Map Opened",
    "Retailer Selection Started",
    "Checkout Sber Spasibo Form Opened",
    "Map Pickup Shop Selected",
    "Checkout Button Clicked", 
    "Checkout Loaded", 
    "Main Page Viewed", 
    "Checkout Slot Selection Started",
    "Checkout Delivery Slot Selection Started",
    "Checkout Delivery Slot Selected", 
    "Cart Viewed", 
    "Search Started", 
    "Banner Viewed", 
    "Recommendation Block View", 
    "Product Category Viewed", 
    "Catalogue Tab Clicked",
    "Add To Cart Clicked", 
    "Onboarding Banner Viewed", 
    "Order Info Viewed", 
    "Product Sort Initiated",
    "Product Filter Initiated",
    "Product Sorted", 
    "Cart Params Loaded",
    "Address Selected", 
    "Address Search Opened",
    "Address Suggest Clicked",
    "Redirected From SBOL",
    "Sberid Authorization Prompt Shown",
    "Map Pickup Button Clicked",
    "Age Confirmation Viewed",
    "Alcohol Pickup Popup_completed",
    "Favorites Tab Clicked",
    "Address Change Clicked",
    "Retailer Selected"
)

sources_web = (
    "Order Completed",
    "Checkout Button Clicked",
    "Landing Viewed",
    "Product Added",
    "Main Page Viewed",
    "Suggester Viewed",
    "Main Page Viewed",
    "Shop Selected",
    "Product Viewed",
    "Recommendation Product View",
    "Search Results Viewed",
    "Category Viewed",
    "Shop Selection Started",
    "Pickup Map Opened",
    "Cart Viewed",
    "Order Merged",
    "Checkout Loaded",
    "Pre Replacements Product Selected",
    "Pre Replacements Product All Choosed",
    "Address Change Initiated",
    "Retailer Shipping Method Clicked",
    "Button Find Stores Clicked",
    "Favourites Tab Clicked",
    "Checkout Slot Selection Started",
    "Checkout Delivery Slot Selection Started",
    "Checkout Delivery Slot Selected",
    "Search Started",
    "Search Completed",
    "Search Suggest Clicked",
    "Suggester Viewed",
    "Banner Viewed",
    "Recommendation Block View",
    "Product Category Viewed",
    "Catalogue Tab Clicked",
    "Add To Cart Clicked",
    "Onboarding Banner Viewed",
    "Order Info Viewed",
    "Product Sort Initiated",
    "Product Filter Initiated",
    "Product Sorted",
    "Cart Params Loaded",
    "Address Selected",
    "Address Search Opened",
    "Address Suggest Clicked",
    "Redirected From SBOL",
    "Sberid Authorization Prompt Shown",
    "Map Pickup Button Clicked",
    "Age Confirmation Viewed",
    "Alcohol Pickup Button Clicked",
    "Address Change Clicked",
    "Only Pickup Popup Viewed",
    "Retailer Selected"
)

# %% [markdown]
# # Метрики

# %% [raw]
# load_dt = dt.date.today()-dt.timedelta(days=3)
# str_load_dt = load_dt.strftime('%Y-%m-%d')

# %% [markdown]
# ## Отмены/замены

# %%
def get_not_found_ratio_oos(platforms, start_date, end_date, sources_web, sources_new_app):

    q = f""" 
    with 
        toDate('{start_date}') as start_date,
        toDate('{end_date}') as end_date,
        
    events as (
        select 
            toString(anonymous_id) as anonymous_id,
            toDate(ts) as dt,
            'web' as platform,
            ifNull(NullIf(tenant, ''), 'sbermarket') as tenant
        from event.web
        where 1=1
            and toDate(ts) between start_date and end_date
            and dwh_dt between start_date and end_date
            and not_bot
            and event in {sources_web}
        group by anonymous_id, dt, platform, tenant

        union all

        select 
            anonymous_id,
            toDate(ts) as dt,
            toString(platform) as platform,
            'sbermarket' as tenant
        from event.new_app
        where 1=1
            and toDate(ts) between start_date and end_date
            and dwh_dt between start_date and end_date
            and event in {sources_new_app}

        group by anonymous_id, dt, platform, tenant
    ),

    filter_events as (
        select
            anonymous_id,
            toDate(min(ts)) as event_dt
        from event.new_app
        where 1=1
            and {event_filter}
            and dwh_dt between start_date and end_date
            and toDate(ts) between start_date and end_date
        group by anonymous_id

        UNION ALL 

        select
            toString(anonymous_id) as anonymous_id,
            toDate(min(ts)) as event_dt
        from event.web
        where 1=1
            and {event_filter}
            and dwh_dt between start_date and end_date
            and toDate(ts) between start_date and end_date
        group by anonymous_id
    ),

    client_id_x_order_id as (
        select distinct
            date,
            uuid,
            anonymous_id,
            if(platform in ('desktop', 'mobile'), 'web', platform) as platform,
            tenant,
            order_id
        from 
            db_bs_ab_admin.ab_platform_materialization_client_id_x_order_id
        where true 
            and date between start_date and end_date
    ),

    ab_groups_x_events as (
        select distinct
            events.anonymous_id as anonymous_id,
            events.platform as platform,
            events.tenant as tenant,
            client_id_x_order_id.order_id as order_id,
            events.dt as events_dt
        from 
            events

            inner join filter_events 
                on events.anonymous_id = filter_events.anonymous_id

            left join client_id_x_order_id
                on events.anonymous_id = client_id_x_order_id.anonymous_id
                and events.dt = client_id_x_order_id.date
                and events.platform = client_id_x_order_id.platform
                and events.tenant = client_id_x_order_id.tenant

        where true
          and filter_events.event_dt <= events_dt
    ),

        shipments as (
            select platform,
                   order_id, 
                   order_number, 
                   completed_at, 
                   sum(item_count) AS total_items,
                   sum(replaced_items_cnt) AS repl,
                   sum(canceled_items_cnt) AS canc ,
                   sum(replaced_items_cnt + canceled_items_cnt) AS not_found,
                   not_found / (total_items + canc) * 100 AS rc_rate
            from analytics.shipments
            where toDate(completed_at) between start_date and end_date
              AND shipment_state = 'shipped'
              AND item_count>0
              AND store_id IN (SELECT store_id FROM sandbox.stores_with_out_of_stock_model)
              and tenant_id = 'sbermarket'
            GROUP BY user_id,
                     order_id,
                     order_number,
                     completed_at,
                     platform
        )

        select platform
             , anonymous_id
             , ab_groups_x_events.order_id as order_number
             , order_id
             , completed_at
             , total_items
             , repl
             , canc
             , not_found
             , rc_rate
          from ab_groups_x_events 
               join shipments on ab_groups_x_events.order_id = shipments.order_number
                             and toDate(shipments.completed_at) = events_dt
        where platform IN {tuple(platforms)}

    """

    return read_sql_query(q)

# %%
read_sql_query("""
SELECT user, query, elapsed, read_rows
  FROM system.processes
""")
# Out:
#                  user                                              query  \
# 0          airflow_ml  with\n    metrics_data_time as (\n        sele...
# 1       boot_dhw_user  \n            with data_fm as (\n             ...
# 2      valeriy_uvarov  SELECT "Custom SQL Query"."Change" AS "Change"...
# 3          airflow_ml  insert into sandbox.ab_tests_results_tmp\nsett...
# 4  anastasiya_mavrina  with \n\n    dates as (\n        select  disti...
# 5       boot_dhw_user              truncate TABLE sandbox.new_users_info
# 6          airflow_ml  with slices as (\nselect\n\tanonymous_id,\n\ts...
# 7  nikita_kryuchenkov  SELECT "Custom SQL Query3"."a" AS "a (Custom S...
# 8       boot_dhw_user  \n        with response_data as\n        (sele...
# 9    andrey_cherevets  \nSELECT user, query, elapsed, read_rows\n  FR...
#
#        elapsed  read_rows
# 0  1976.868962  401289077
# 1   224.555099  147301960
# 2    49.964400   34661800
# 3    49.689980    4880362
# 4    30.003126  328577878
# 5    20.887456          0
# 6    18.379575   25423857
# 7     9.974009   10447415
# 8     1.047232    3079539
# 9     0.001514          0

# %%
# %%time
test_nf = get_not_found_ratio_oos(['android','web'], end_date, end_date, sources_web, sources_new_app)
# Out:
# CPU times: user 418 ms, sys: 66.7 ms, total: 485 ms
# Wall time: 7.69 s

# %%
test_nf.shape
# Out:
# (46421, 10)

# %%
test_nf.head()
# Out:
#   platform                          anonymous_id order_number    order_id  \
# 0      web  88255aa6-7aba-46c2-a117-17ffa297124b   R574410566  R574410566
# 1      web  a5a6f05f-13b7-465f-bcc7-14d63d426a07   R680336473  R680336473
# 2      web  61bc2cab-afb3-4bc8-9cb4-0996c9c02ca0   R505318176  R505318176
# 3      web  14055d9f-7762-48e0-bc1a-377aa9ff0e5d   R202717654  R202717654
# 4      web  55880faa-0ceb-4d44-bbb1-b2476bdacaff   R282634577  R282634577
#
#          completed_at  total_items  repl  canc  not_found    rc_rate
# 0 2023-11-06 09:46:40            6     0     0          0   0.000000
# 1 2023-11-06 05:14:38            2     0     0          0   0.000000
# 2 2023-11-06 10:24:34           18     2     0          2  11.111111
# 3 2023-11-06 09:00:46            5     1     0          1  20.000000
# 4 2023-11-06 03:40:09           38     0     2          2   5.000000

# %%
(
    test_nf
    .groupby(['platform'])
    [['total_items','not_found']].sum()
    .assign(rc_rate = lambda _df: _df.not_found/_df.total_items*100)
)
# Out:
#           total_items  not_found   rc_rate
# platform
# android        570858      38210  6.693433
# web             51115       3340  6.534285

# %%
test_nf.platform.value_counts()
# Out:
# android    42430
# web         3991
# Name: platform, dtype: int64

# %% [markdown]
# ## Время_сборки

# %%
def get_collection_time_ratio_oos(platforms, start_date, end_date, sources_web, sources_new_app):

    req = f""" 
    with toDate('{start_date}') as start_date, 
         toDate('{end_date}') as end_date, 

    events as (
        select 
            toString(anonymous_id) as anonymous_id,
            toDate(ts) as dt,
            'web' as platform,
            ifNull(NullIf(tenant, ''), 'sbermarket') as tenant
        from event.web
        where 1=1
            and toDate(ts) between start_date and end_date
            and dwh_dt between start_date and end_date
            and not_bot
            and event in {sources_web}
        group by anonymous_id, dt, platform, tenant

        union all

        select 
            anonymous_id,
            toDate(ts) as dt,
            toString(platform) as platform,
            'sbermarket' as tenant
        from event.new_app
        where 1=1
            and toDate(ts) between start_date and end_date
            and dwh_dt between start_date and end_date
            and event in {sources_new_app}

        group by anonymous_id, dt, platform, tenant
    ),

    filter_events as (
        select
            anonymous_id,
            toDate(min(ts)) as event_dt
        from event.new_app
        where 1=1
            and {event_filter}
            and dwh_dt between start_date and end_date
            and toDate(ts) between start_date and end_date
        group by anonymous_id

        UNION ALL 

        select
            toString(anonymous_id) as anonymous_id,
            toDate(min(ts)) as event_dt
        from event.web
        where 1=1
            and {event_filter}
            and dwh_dt between start_date and end_date
            and toDate(ts) between start_date and end_date
        group by anonymous_id
    ),

    client_id_x_order_id as (
        select distinct
            date,
            uuid,
            anonymous_id,
            if(platform in ('desktop', 'mobile'), 'web', platform) as platform,
            tenant,
            order_id
        from 
            db_bs_ab_admin.ab_platform_materialization_client_id_x_order_id
        where true 
            and date between start_date and end_date
    ),

    ab_groups_x_events as (
        select distinct
            events.anonymous_id as anonymous_id,
            events.platform as platform,
            events.tenant as tenant,
            client_id_x_order_id.order_id as order_id,
            events.dt as events_dt
        from 
            events

            inner join filter_events 
                on events.anonymous_id = filter_events.anonymous_id

            left join client_id_x_order_id
                on events.anonymous_id = client_id_x_order_id.anonymous_id
                and events.dt = client_id_x_order_id.date
                and events.platform = client_id_x_order_id.platform
                and events.tenant = client_id_x_order_id.tenant

        where true
          and filter_events.event_dt <= events_dt
    ),
         

        shpmnts as (
            select platform,
                   order_id, 
                   order_number, 
                   shipment_number AS shipment_number,
                   completed_at
            from analytics.shipments
            where toDate(completed_at) between start_date and end_date
              AND shipment_state = 'shipped'
              AND store_id IN (SELECT store_id FROM sandbox.stores_with_out_of_stock_model)
        ),
        
        collection_time AS (
        SELECT shipment_number AS shipment_number,
               start_assembling_to_first_item * ifNull(start_to_first_item_coef, 1)   
               + items_collection_time * ifNull(items_collection_time_coef, 1)                            
               + last_item_to_cashing_started * ifNull(last_item_to_cashing_coef, 1) as assembly_speed_positions_num 
          FROM sandbox.cte_decomposition_new
         WHERE toDate(completed_at) between start_date and end_date
           AND overall_time_of_order is not null
           AND shipped_at IS NOT NULL
        ),
        
        prep AS (
        SELECT order_number,
               order_id,
               completed_at,
               count(distinct(shipment_number)) AS n_shipments,
               SUM(assembly_speed_positions_num) AS assembly_speed_positions_num
          FROM shpmnts
               JOIN collection_time ON collection_time.shipment_number = shpmnts.shipment_number
         GROUP BY order_number,
                  order_id,
                  completed_at
        )

        select platform
             , anonymous_id
             , ab_groups_x_events.order_id as order_number
             , order_id
             , completed_at
             , n_shipments
             , assembly_speed_positions_num
          from ab_groups_x_events 
               join prep on ab_groups_x_events.order_id = prep.order_number
                        and toDate(prep.completed_at) = events_dt
         where platform IN {tuple(platforms)}
    """

    all_orders = read_sql_query(req)
    return all_orders

# %%
# %%time
test_ct = get_collection_time_ratio_oos(['android','web'], end_date, end_date, sources_web, sources_new_app)
# Out:
# CPU times: user 323 ms, sys: 30.9 ms, total: 354 ms
# Wall time: 8.66 s

# %%
test_ct.shape
# Out:
# (30036, 7)

# %%
test_ct.head()
# Out:
#   platform                          anonymous_id order_number    order_id  \
# 0      web  31456cad-b1c2-4094-84c9-879358717131   R001412846  R001412846
# 1      web  a3835cd0-a694-4d4e-b8d4-ff6f5c7ff230   R164870386  R164870386
# 2      web  0cdbdcf4-504e-4645-9ec7-d930f74a5db4   R188047662  R188047662
# 3      web  0bb9072b-339a-40be-8a7e-61289b7800fb   R145678416  R145678416
# 4      web  b620a5aa-f97b-4c91-be68-5f95a69a2e84   R250408425  R250408425
#
#          completed_at  n_shipments  assembly_speed_positions_num
# 0 2023-11-06 13:33:40            1                         921.0
# 1 2023-11-06 07:28:22            1                        1178.5
# 2 2023-11-06 08:22:50            1                        1280.5
# 3 2023-11-06 08:59:41            1                        1436.0
# 4 2023-11-06 09:21:06            1                        1476.0

# %%
(
    test_ct
    .groupby(['platform'])
    [['n_shipments','assembly_speed_positions_num']].sum()
    .assign(rc_rate = lambda _df: _df.assembly_speed_positions_num/_df.n_shipments)
)
# Out:
#           n_shipments  assembly_speed_positions_num      rc_rate
# platform
# android         26963                  3.835186e+07  1422.388612
# web              3074                  4.168902e+06  1356.181616

# %%
test_ct.platform.value_counts()
# Out:
# android    26962
# web         3074
# Name: platform, dtype: int64

# %% [markdown]
# ## AOV_goods

# %%
def get_aov_goods_ratio_oos(platforms, start_date, end_date, sources_web, sources_new_app):

    q = f""" 
    with 
        toDate('{start_date}') as start_date,
        toDate('{end_date}') as end_date,

    events as (
        select 
            toString(anonymous_id) as anonymous_id,
            toDate(ts) as dt,
            'web' as platform,
            ifNull(NullIf(tenant, ''), 'sbermarket') as tenant
        from event.web
        where 1=1
            and toDate(ts) between start_date and end_date
            and dwh_dt between start_date and end_date
            and not_bot
            and event in {sources_web}
        group by anonymous_id, dt, platform, tenant

        union all

        select 
            anonymous_id,
            toDate(ts) as dt,
            toString(platform) as platform,
            'sbermarket' as tenant
        from event.new_app
        where 1=1
            and toDate(ts) between start_date and end_date
            and dwh_dt between start_date and end_date
            and event in {sources_new_app}

        group by anonymous_id, dt, platform, tenant
    ),

    filter_events as (
        select
            anonymous_id,
            toDate(min(ts)) as event_dt
        from event.new_app
        where 1=1
            and {event_filter}
            and dwh_dt between start_date and end_date
            and toDate(ts) between start_date and end_date
        group by anonymous_id

        UNION ALL 

        select
            toString(anonymous_id) as anonymous_id,
            toDate(min(ts)) as event_dt
        from event.web
        where 1=1
            and {event_filter}
            and dwh_dt between start_date and end_date
            and toDate(ts) between start_date and end_date
        group by anonymous_id
    ),

    client_id_x_order_id as (
        select distinct
            date,
            uuid,
            anonymous_id,
            if(platform in ('desktop', 'mobile'), 'web', platform) as platform,
            tenant,
            order_id
        from 
            db_bs_ab_admin.ab_platform_materialization_client_id_x_order_id
        where true 
            and date between start_date and end_date
    ),

    ab_groups_x_events as (
        select distinct
            events.anonymous_id as anonymous_id,
            events.platform as platform,
            events.tenant as tenant,
            client_id_x_order_id.order_id as order_id,
            events.dt as events_dt
        from 
            events

            inner join filter_events 
                on events.anonymous_id = filter_events.anonymous_id

            left join client_id_x_order_id
                on events.anonymous_id = client_id_x_order_id.anonymous_id
                and events.dt = client_id_x_order_id.date
                and events.platform = client_id_x_order_id.platform
                and events.tenant = client_id_x_order_id.tenant

        where true
          and filter_events.event_dt <= events_dt
    ),

    fin_measures as (
        select 
            order_number,
            completed_at,
            sum(goods) AS goods
        from analytics.financial_measures
        where 1=1
            and toDate(completed_at) between start_date and end_date
            AND store_id IN (SELECT store_id FROM sandbox.stores_with_out_of_stock_model)
            and user_id is not null
            and order_state = 'complete'
            and shipment_state = 'shipped'
            and b2b_order_company_flg != 1
            and b2b_measure = 0
            and order_number not in 
            (
                select order_number
                from analytics.shipments
                where 1=1
                    and toDate(completed_at) between start_date and end_date + interval 14 day
                    and owner_type = 'ServiceAccount'
            )
        group by order_number, completed_at
    )
    
    select platform
         , anonymous_id
         , ab_groups_x_events.order_id as order_number
         , goods
      from ab_groups_x_events 
           join fin_measures ON fin_measures.order_number = ab_groups_x_events.order_id
                             and toDate(fin_measures.completed_at) = events_dt

     where platform IN {tuple(platforms)}

    """

    return read_sql_query(q)

# %%
# %%time
test_aov = get_aov_goods_ratio_oos(['android','web'], end_date, end_date, sources_web, sources_new_app)
# Out:
# CPU times: user 202 ms, sys: 24.1 ms, total: 226 ms
# Wall time: 5.79 s

# %%
test_aov.shape
# Out:
# (45022, 4)

# %%
test_aov.head()
# Out:
#   platform                          anonymous_id order_number        goods
# 0      web  bae7a329-8395-49a2-baff-17c7d55dcb25   R175335542  1559.579956
# 1      web  bf028c65-5d44-4130-bbe1-5b454b520c94   R338665354  2630.469971
# 2      web  d893f643-7c66-4063-9c4d-1afbfa28deab   R401744640  5024.319824
# 3      web  77374306-461f-451f-bbb5-ff37199c719c   R543260435  1506.900024
# 4      web  0b2280f4-9be2-4ad0-814b-7bc0dfbecf74   R682548828  3917.280029

# %%
test_aov.platform.value_counts()
# Out:
# android    41272
# web         3750
# Name: platform, dtype: int64

# %%
(
    test_aov
    .groupby(['platform','anonymous_id'])
    .agg({
            'order_number':'nunique',
            'goods':'sum'
        })
    .reset_index()
    .groupby('platform')
    [['goods','order_number']].sum()
    .assign(aov = lambda _df: _df.goods/_df.order_number)
)
# Out:
#                  goods  order_number          aov
# platform
# android   9.338222e+07         41272  2262.604773
# web       9.763435e+06          3750  2603.582751

# %% [markdown]
# ## AOV_первичный

# %%
def get_initial_aov_goods_ratio_oos(platforms, start_date, end_date, sources_web, sources_new_app):
        
    req = f""" 
    with 
            toDate('{start_date}') as start_date,
            toDate('{end_date}') as end_date,

        events as (
            select 
                toString(anonymous_id) as anonymous_id,
                toDate(ts) as dt,
                'web' as platform,
                ifNull(NullIf(tenant, ''), 'sbermarket') as tenant
            from event.web
            where 1=1
                and toDate(ts) between start_date and end_date
                and dwh_dt between start_date and end_date
                and not_bot
                and event in {sources_web}
            group by anonymous_id, dt, platform, tenant

            union all

            select 
                anonymous_id,
                toDate(ts) as dt,
                toString(platform) as platform,
                'sbermarket' as tenant
            from event.new_app
            where 1=1
                and toDate(ts) between start_date and end_date
                and dwh_dt between start_date and end_date
                and event in {sources_new_app}

            group by anonymous_id, dt, platform, tenant
        ),

        filter_events as (
            select
                anonymous_id,
                toDate(min(ts)) as event_dt
            from event.new_app
            where 1=1
                and {event_filter}
                and dwh_dt between start_date and end_date
                and toDate(ts) between start_date and end_date
            group by anonymous_id

            UNION ALL 

            select
                toString(anonymous_id) as anonymous_id,
                toDate(min(ts)) as event_dt
            from event.web
            where 1=1
                and {event_filter}
                and dwh_dt between start_date and end_date
                and toDate(ts) between start_date and end_date
            group by anonymous_id
        ),

        client_id_x_order_id as (
            select distinct
                date,
                uuid,
                anonymous_id,
                if(platform in ('desktop', 'mobile'), 'web', platform) as platform,
                tenant,
                order_id
            from 
                db_bs_ab_admin.ab_platform_materialization_client_id_x_order_id
            where true 
                and date between start_date and end_date
        ),

        ab_groups_x_events as (
            select distinct
                events.anonymous_id as anonymous_id,
                events.platform as platform,
                events.tenant as tenant,
                client_id_x_order_id.order_id as order_id,
                events.dt as events_dt

            from 
                events

                inner join filter_events 
                    on events.anonymous_id = filter_events.anonymous_id

                left join client_id_x_order_id
                    on events.anonymous_id = client_id_x_order_id.anonymous_id
                    and events.dt = client_id_x_order_id.date
                    and events.platform = client_id_x_order_id.platform
                    and events.tenant = client_id_x_order_id.tenant

            where true
              and filter_events.event_dt <= events_dt
        ),
        
        li as (

            SELECT order_number,
                   order_completed_at,
                   sumIf(

                   coalesce(coalesce(toFloat32(if(assembly_issue like 'Собран%%шт%%'or assembly_issue like 'Собран%%уп%%', extract(substring(assembly_issue, position(assembly_issue, 'из') + 4), '[\d]*[\d]'), null)),
                    toFloat32(if(assembly_issue like 'Собран%%кг%%', replace(replace(substring(assembly_issue, position(assembly_issue, 'из') + 4), 'кг.', ''), ' ', ''), null))), quantity)*

                    price,

                    li_created_at <= order_completed_at
                   ) AS aov_initial_before,

                   sumIf(price*quantity,li_deleted_at IS NULL) AS aov_initial_after
              FROM line_items
             WHERE store_id IN (SELECT store_id FROM sandbox.stores_with_out_of_stock_model)
               AND order_state = 'complete'
               AND shipment_state = 'shipped'
            -- AND store_id IN (SELECT DISTINCT store_id FROM sandbox.stores_with_out_of_stock_model)
            -- AND li_created_at <= order_completed_at
               AND not (li_deleted_at is not null and assembly_issue is null) -- НЕ сами удалили позицию в рамках заказа
               AND toDate(order_completed_at) between start_date and end_date
               AND order_number not in 
                (
                    select order_number
                    from analytics.shipments
                    where 1=1
                        and toDate(completed_at) between start_date and end_date + interval 14 day
                        and owner_type = 'ServiceAccount'
                    UNION ALL

                    SELECT order_number 
                     from analytics.financial_measures
                    WHERE 1=1
                      AND toDate(completed_at) between start_date and end_date + interval 14 day
                      AND (b2b_order_company_flg = 1 OR b2b_measure != 0)
                )
             GROUP BY order_number, order_completed_at

            )


        select platform
                 , anonymous_id
                 , ab_groups_x_events.order_id as order_number
                 , aov_initial_before
                 , aov_initial_after
              from ab_groups_x_events 
                   join li on ab_groups_x_events.order_id = li.order_number
                           and toDate(li.order_completed_at) = events_dt

             where platform IN {tuple(platforms)}
    """

    all_orders = read_sql_query(req)
    return all_orders

# %%
# %%time
test_aov_init = get_initial_aov_goods_ratio_oos(['android','web'], end_date, end_date, sources_web, sources_new_app)
# Out:
# CPU times: user 193 ms, sys: 33.2 ms, total: 227 ms
# Wall time: 32.4 s

# %%
test_aov_init.shape
# Out:
# (45023, 5)

# %%
test_aov_init.head()
# Out:
#   platform                          anonymous_id order_number  \
# 0      web  88255aa6-7aba-46c2-a117-17ffa297124b   R574410566
# 1      web  a5a6f05f-13b7-465f-bcc7-14d63d426a07   R680336473
# 2      web  61bc2cab-afb3-4bc8-9cb4-0996c9c02ca0   R505318176
# 3      web  14055d9f-7762-48e0-bc1a-377aa9ff0e5d   R202717654
# 4      web  55880faa-0ceb-4d44-bbb1-b2476bdacaff   R282634577
#
#    aov_initial_before  aov_initial_after
# 0         2471.149935        2538.379938
# 1         3779.949951        3779.949951
# 2         5587.476456        5102.859966
# 3          384.819996         442.820004
# 4         2604.940031        2524.960028

# %%
test_aov_init.platform.value_counts()
# Out:
# android    41273
# web         3750
# Name: platform, dtype: int64

# %%
(
    test_aov_init
    .groupby(['platform','anonymous_id'])
    .agg({
            'order_number':'nunique',
            'aov_initial_before':'sum',
            'aov_initial_after':'sum'
        })
    .reset_index()
    .groupby('platform')
    [['aov_initial_after','aov_initial_before','order_number']].sum()
    .assign(aov_before = lambda _df: _df.aov_initial_before/_df.order_number)
    .assign(aov_after = lambda _df: _df.aov_initial_after/_df.order_number)
)
# Out:
#           aov_initial_after  aov_initial_before  order_number   aov_before  \
# platform
# android        9.334553e+07        9.889055e+07         41273  2396.010599
# web            9.759176e+06        1.028381e+07          3750  2742.349537
#
#             aov_after
# platform
# android   2261.660788
# web       2602.446815

# %%
(
    test_aov
    .groupby(['platform','anonymous_id'])
    .agg({
            'order_number':'nunique',
            'goods':'sum'
        })
    .reset_index()
    .groupby('platform')
    [['goods','order_number']].sum()
    .assign(aov = lambda _df: _df.goods/_df.order_number)
)
# Out:
#                  goods  order_number          aov
# platform
# android   9.338222e+07         41272  2262.604773
# web       9.763435e+06          3750  2603.582751

# %% [markdown]
# ## Retention

# %%
def get_general_metrics_oos(platforms, start_date, end_date, sources_web, sources_new_app):
    q = f"""
    with 
        toDate('{start_date}') as start_date,
        toDate('{end_date}') as end_date,

    events as (
        select 
            toString(anonymous_id) as anonymous_id,
            toDate(ts) as dt,
            'web' as platform,
            ifNull(NullIf(tenant, ''), 'sbermarket') as tenant
        from event.web
        where 1=1
            and toDate(ts) between start_date and end_date
            and dwh_dt between start_date and end_date
            and not_bot
            and event in {sources_web}
        group by anonymous_id, dt, platform, tenant

        union all

        select 
            anonymous_id,
            toDate(ts) as dt,
            toString(platform) as platform,
            'sbermarket' as tenant
        from event.new_app
        where 1=1
            and toDate(ts) between start_date and end_date
            and dwh_dt between start_date and end_date
            and event in {sources_new_app}

        group by anonymous_id, dt, platform, tenant
    ),

    filter_events as (
        select
            anonymous_id,
            toDate(min(ts)) as event_dt
        from event.new_app
        where 1=1
            and {event_filter}
            and dwh_dt between start_date and end_date
            and toDate(ts) between start_date and end_date
        group by anonymous_id

        UNION ALL 

        select
            toString(anonymous_id) as anonymous_id,
            toDate(min(ts)) as event_dt
        from event.web
        where 1=1
            and {event_filter}
            and dwh_dt between start_date and end_date
            and toDate(ts) between start_date and end_date
        group by anonymous_id
    ),

    client_id_x_order_id as (
        select distinct
            date,
            uuid,
            anonymous_id,
            if(platform in ('desktop', 'mobile'), 'web', platform) as platform,
            tenant,
            order_id
        from 
            db_bs_ab_admin.ab_platform_materialization_client_id_x_order_id
        where true 
            and date between start_date and end_date
    ),

    ab_groups_x_events as (
        select distinct
            events.anonymous_id as anonymous_id,
            events.platform as platform,
            events.tenant as tenant,
            client_id_x_order_id.order_id as order_id,
            events.dt as events_dt
        from 
            events

            inner join filter_events 
                on events.anonymous_id = filter_events.anonymous_id

            left join client_id_x_order_id
                on events.anonymous_id = client_id_x_order_id.anonymous_id
                and events.dt = client_id_x_order_id.date
                and events.platform = client_id_x_order_id.platform
                and events.tenant = client_id_x_order_id.tenant

        where true
          and filter_events.event_dt <= events_dt
    ),

    late_cancelled_orders as (
     select 
           stateful_id as order_id,
           minIf(toDate(created_at), next_state = 'complete') as completed_at,
           minIf(toDate(created_at), next_state = 'canceled') as canceled_at,
           if((canceled_at < completed_at + interval 2 day or canceled_at < end_date) and canceled_at > toDate('1970-01-01'), 1, 0) as late_cancel_flg
      from (
      select stateful_type,
            created_at,
            next_state,
            stateful_id
        from analytics.int_spree_state_changes  
       where stateful_type = 'Spree::Order'
         and toDate(created_at) between start_date and end_date
         and next_state in ('complete', 'canceled')
        order by created_at) issc
     group by stateful_id
    having completed_at is not null
       and late_cancel_flg
    ),

    financial_measures as (
        select 
            uuid,
            order_number,
            toDate(completed_at) as completed_dt,
            max(shipped_at) as shipped_at,
            sumIf(1, type_delivery=='asap') as express_flg,
            sumIf(1, type_delivery=='planned') as planned_flg,
            sumIf(1, type_delivery=='pickup') as pickup_flg,
            sumIf(gmv_advertising, type_delivery = 'asap') + sumIf(gmv_service_fee_net_promo, type_delivery = 'asap') + sumIf(gmv_goods_net_promo, type_delivery = 'asap') as gmv_net_of_promo_express,
            sumIf(gmv_advertising, type_delivery = 'planned') + sumIf(gmv_service_fee_net_promo, type_delivery = 'planned') + sumIf(gmv_goods_net_promo, type_delivery = 'planned') as gmv_net_of_promo_planned,
            sumIf(gmv_advertising, type_delivery = 'pickup') + sumIf(gmv_service_fee_net_promo, type_delivery = 'pickup') + sumIf(gmv_goods_net_promo, type_delivery = 'pickup') as gmv_net_of_promo_pickup,
            sum(gmv_advertising) + sum(gmv_service_fee_net_promo) + sum(gmv_goods_net_promo) as gmv_net_of_promo,
            sumIf(gross_profit, type_delivery = 'asap') as gross_profit_express,
            sumIf(gross_profit, type_delivery = 'planned') as gross_profit_planned,
            sumIf(gross_profit, type_delivery = 'pickup') as gross_profit_pickup,
            sum(gross_profit) as gross_profit_full

        from analytics.financial_measures
        where 1=1
            and store_id IN (SELECT store_id FROM sandbox.stores_with_out_of_stock_model)
            and toDate(completed_at) between start_date and end_date
            and user_id is not null
            and order_state in ('complete', 'canceled')
            and b2b_order_company_flg != 1
            and b2b_measure = 0
            and order_id not in (select order_id from late_cancelled_orders)
            and order_number not in 
            (
                select order_number
                from analytics.shipments
                where 1=1
                    and toDate(completed_at) between start_date and end_date + interval 14 day
                    and owner_type = 'ServiceAccount'
            )
        group by dictGet('analytics.spree_users_dict', 'uuid', toUInt64(user_id)) as uuid, order_number, completed_at
        )

    select 
        anonymous_id,
        platform,
        tenant,
        sumIf(gmv_net_of_promo, completed_dt = events_dt) as gmv_per_user_within_retilist, -- это значение может быть использовано как числитель для ratio метрики среднего чека
        uniqExactIf(order_id, uuid != '' and completed_dt = events_dt) as orders_within_retilist, -- это значение может быть использовано как знаменатель для ratio метрики среднего чека
        max(if(uuid != '' and completed_dt = events_dt, 1, 0)) as conversion_within_retilist,
        minIf(completed_dt, completed_dt = events_dt) as first_order_date,  
        arrayExists(elem -> assumeNotNull(elem <= toDate(first_order_date + INTERVAL 14 DAY) and elem > first_order_date), groupArray(toDate(shipped_at))) as ret_14d_within_retilist
    from ab_groups_x_events
    left join (select * from financial_measures where completed_dt >= start_date and completed_dt <= end_date + interval 14 day) financial_measures
        on order_id = order_number
    where tenant = 'sbermarket'
    group by anonymous_id, platform, tenant
   HAVING platform IN {tuple(platforms)}
    """
    return read_sql_query(q)

# %%
test_general = get_general_metrics_oos(['android','web'], end_date, end_date, sources_web, sources_new_app)

# %%
test_general.shape
# Out:
# (261466, 8)

# %%
test_general.head()
# Out:
#        anonymous_id platform      tenant  gmv_per_user_within_retilist  \
# 0  9ae7a98c748b90e3  android  sbermarket                   1869.057169
# 1  b301bae22776e8e1  android  sbermarket                      0.000000
# 2  58a97bf43c4f1376  android  sbermarket                   2595.019643
# 3  90e5f0104adbf1af  android  sbermarket                      0.000000
# 4  10b0d179d5bbe86d  android  sbermarket                    645.739809
#
#    orders_within_retilist  conversion_within_retilist first_order_date  \
# 0                       1                           1       2023-11-06
# 1                       0                           0             None
# 2                       1                           1       2023-11-06
# 3                       0                           0             None
# 4                       1                           1       2023-11-06
#
#    ret_14d_within_retilist
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0

# %%
test_general.platform.value_counts()
# Out:
# android    219082
# web         42384
# Name: platform, dtype: int64

# %%
(
    test_general
    .groupby('platform')
    .ret_14d_within_retilist.max()
)
# Out:
# platform
# android    0
# web        0
# Name: ret_14d_within_retilist, dtype: int64

# %% [markdown]
# # MDE

# %% [markdown]
# ## Data_collection

# %%
import pickle

def dump_data(data_name, file_path):
    """
    Дампинг данных 
    
    :param data_name: файл 
    :param file_path: str, путь до файла 
    """
    with open(file_path, "wb") as f:
        pickle.dump(data_name, f)

def load_data(data_path):
    """
    Загрузка файла 
    
    :param data_path: str, путь до файла 
    """
    with open(data_path, 'rb') as f:
        data_name = pickle.load(f)
    return data_name

# %% [markdown]
# ### Отмены/замены_load

# %%
not_found_data = {}
for l in tqdm(lengths):
    name = f"{l}w"
    tmp = get_not_found_ratio_oos(platforms, end_date - dt.timedelta(weeks = l), end_date,  sources_web, sources_new_app)
    not_found_data[name] = tmp
# Out:
# 100%|██████████| 3/3 [27:07<00:00, 542.46s/it]

# %%
dump_data(not_found_data,'not_found_data.pickle')

# %% [markdown]
# ### Время_сборки_load

# %%
collection_data = {}
for l in tqdm(lengths):
    name = f"{l}w"
    tmp = get_collection_time_ratio_oos(platforms, end_date - dt.timedelta(weeks = l), end_date,  sources_web, sources_new_app)
    collection_data[name] = tmp
# Out:
# 100%|██████████| 3/3 [27:35<00:00, 551.92s/it]

# %%
dump_data(collection_data,'collection_data.pickle')

# %% [markdown]
# ### AOV_goods_load

# %%
aov_data = {}
for l in tqdm(lengths):
    name = f"{l}w"
    tmp = get_aov_goods_ratio_oos(platforms, end_date - dt.timedelta(weeks = l), end_date,  sources_web, sources_new_app)
    aov_data[name] = tmp
# Out:
# 100%|██████████| 3/3 [26:26<00:00, 528.81s/it]

# %%
dump_data(aov_data,'aov_data.pickle')

# %% [markdown]
# ### AOV_goods_initial_load

# %%
aov_initial_data = {}
for l in tqdm(lengths):
    name = f"{l}w"
    tmp = get_initial_aov_goods_ratio_oos(platforms, end_date - dt.timedelta(weeks = l), end_date,  sources_web, sources_new_app)
    aov_initial_data[name] = tmp
# Out:
# 100%|██████████| 3/3 [27:00<00:00, 540.08s/it]

# %%
dump_data(aov_initial_data,'aov_initial_data.pickle')

# %% [markdown]
# ### Retention

# %%
retention_data = {}
for l in tqdm(lengths):
    name = f"{l}w"
    tmp = get_general_metrics_oos(platforms, end_date - dt.timedelta(weeks = l), end_date,  sources_web, sources_new_app)
    retention_data[name] = tmp
# Out:
# 100%|██████████| 3/3 [26:15<00:00, 525.05s/it]

# %%
dump_data(retention_data,'retention_data.pickle')

# %% [markdown]
# ## Data_preprocessing

# %% [markdown]
# ### Отмены/замены_prep

# %%
# %%time
for item in not_found_data:
    t = not_found_data[item]
    t = t.groupby(["anonymous_id", "platform"])[['not_found','total_items']].sum().reset_index()
    not_found_data[item] = t
# Out:
# CPU times: user 6.78 s, sys: 137 ms, total: 6.91 s
# Wall time: 6.9 s

# %%
not_found_data['4w'].platform.value_counts()
# Out:
# android    683482
# web        114477
# Name: platform, dtype: int64

# %% [markdown]
# ### Время_сборки_prep

# %%
# %%time
for item in collection_data:
    t = collection_data[item]
    t = t.groupby(["anonymous_id", "platform"])[['assembly_speed_positions_num','n_shipments']].sum().reset_index()
    collection_data[item] = t
# Out:
# CPU times: user 4.65 s, sys: 2.66 ms, total: 4.65 s
# Wall time: 4.69 s

# %%
collection_data['4w'].platform.value_counts()
# Out:
# android    531832
# web        100273
# Name: platform, dtype: int64

# %% [markdown]
# ### AOV_goods_prep

# %%
# %%time
for item in aov_data:
    t = aov_data[item]
    t = t.groupby(["anonymous_id", "platform"]).agg({'goods':'sum','order_number':'nunique'}).reset_index()
    aov_data[item] = t
# Out:
# CPU times: user 7.99 s, sys: 0 ns, total: 7.99 s
# Wall time: 8.1 s

# %%
aov_data['4w'].platform.value_counts()
# Out:
# android    669200
# web        107118
# Name: platform, dtype: int64

# %% [markdown]
# ### AOV_initial_prep

# %%
aov_initial_data['2w'].head()
# Out:
#   platform                          anonymous_id order_number  \
# 0      web  00540057-4c46-460e-8f4b-352be27d090e   R348772771
# 1      web  013dd674-8cb4-4869-b5c4-8dc6b21bc1de   R535705004
# 2      web  017e491f-3956-4a4c-bc4c-0affbb7534e8   R300857222
# 3      web  031ae5bf-3f65-444c-be06-10b6d31167c0   R271260184
# 4      web  032a2b2f-e96e-4d15-aa16-73e2e909f4ce   R301703084
#
#    aov_initial_before  aov_initial_after
# 0         2050.470009        2050.470009
# 1         2768.809998        2340.809998
# 2         5256.139893        2628.069946
# 3         1494.599989        1494.599989
# 4        10856.035005       11038.729998

# %%
# %%time
for item in aov_initial_data:
    t = aov_initial_data[item]
    t = t.groupby(["anonymous_id", "platform"]).agg({'aov_initial_before':'sum','aov_initial_after':'sum','order_number':'nunique'}).reset_index()
    aov_initial_data[item] = t
# Out:
# CPU times: user 9.52 s, sys: 20.4 ms, total: 9.54 s
# Wall time: 9.56 s

# %%
aov_initial_data['4w'].platform.value_counts()
# Out:
# android    669183
# web        107152
# Name: platform, dtype: int64

# %% [markdown]
# ### Retention

# %%
retention_data['4w'].anonymous_id.value_counts().max()
# Out:
# 1

# %% [markdown]
# ### Итог

# %%
final_data = {}
for l in tqdm(lengths):
    name = f"{l}w"
    not_found_tmp = not_found_data[name].copy()
    col_tmp = collection_data[name].copy()
    aov_tmp = aov_data[name].copy()
    aov_initial_tmp = aov_initial_data[name].copy()
    retention_data_tmp = retention_data[name].copy()
    out = (
        not_found_tmp
        .merge(col_tmp, on = ['platform','anonymous_id'],how = 'outer')
        .merge(aov_tmp, on = ['platform','anonymous_id'],how = 'outer')
        .merge(aov_initial_tmp, on = ['platform','anonymous_id'],how = 'outer')
        .merge(retention_data_tmp, on = ['platform','anonymous_id'],how='outer')
    )
    final_data[name] = out
# Out:
# 100%|██████████| 3/3 [00:31<00:00, 10.66s/it]

# %%
final_data['2w'].isna().sum()
# Out:
# anonymous_id                          0
# platform                              0
# not_found                       1349167
# total_items                     1349167
# assembly_speed_positions_num    1468325
# n_shipments                     1468325
# goods                           1363537
# order_number_x                  1363537
# aov_initial_before              1363521
# aov_initial_after               1363521
# order_number_y                  1363521
# tenant                             4739
# gmv_per_user_within_retilist       4739
# orders_within_retilist             4739
# conversion_within_retilist         4739
# first_order_date                1347855
# ret_14d_within_retilist            4739
# dtype: int64

# %%
# Проверям пустые чеки (исходные)

# %%
final_data['2w'].query('oos_aov_initial_num != oos_aov_initial_num').query('goods==goods')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     200             if self.has_resolvers:
# --> 201                 return self.resolvers[key]
#     202
#
# /opt/conda/lib/python3.9/collections/__init__.py in __getitem__(self, key)
#     940                 pass
# --> 941         return self.__missing__(key)            # support subclasses that define __missing__
#     942
#
# /opt/conda/lib/python3.9/collections/__init__.py in __missing__(self, key)
#     932     def __missing__(self, key):
# --> 933         raise KeyError(key)
#     934
#
# KeyError: 'oos_aov_initial_num'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     211                 # e.g., df[df > 0]
# --> 212                 return self.temps[key]
#     213             except KeyError as err:
#
# KeyError: 'oos_aov_initial_num'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# /tmp/ipykernel_792/3609437321.py in <module>
# ----> 1 final_data['2w'].query('oos_aov_initial_num != oos_aov_initial_num').query('goods==goods')
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    3467         kwargs["level"] = kwargs.pop("level", 0) + 1
#    3468         kwargs["target"] = None
# -> 3469         res = self.eval(expr, **kwargs)
#    3470
#    3471         try:
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    3597         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    3598
# -> 3599         return _eval(expr, inplace=inplace, **kwargs)
#    3600
#    3601     def select_dtypes(self, include=None, exclude=None) -> DataFrame:
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     340         )
#     341
# --> 342         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     343
#     344         # construct the engine and evaluate the parsed expression
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/expr.py in __init__(self, expr, engine, parser, env, level)
#     796         self.parser = parser
#     797         self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 798         self.terms = self.parse()
#     799
#     800     @property
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/expr.py in parse(self)
#     815         Parse an expression.
#     816         """
# --> 817         return self._visitor.visit(self.expr)
#     818
#     819     @property
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     399         method = "visit_" + type(node).__name__
#     400         visitor = getattr(self, method)
# --> 401         return visitor(node, **kwargs)
#     402
#     403     def visit_Module(self, node, **kwargs):
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/expr.py in visit_Module(self, node, **kwargs)
#     405             raise SyntaxError("only a single expression is allowed")
#     406         expr = node.body[0]
# --> 407         return self.visit(expr, **kwargs)
#     408
#     409     def visit_Expr(self, node, **kwargs):
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     399         method = "visit_" + type(node).__name__
#     400         visitor = getattr(self, method)
# --> 401         return visitor(node, **kwargs)
#     402
#     403     def visit_Module(self, node, **kwargs):
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/expr.py in visit_Expr(self, node, **kwargs)
#     408
#     409     def visit_Expr(self, node, **kwargs):
# --> 410         return self.visit(node.value, **kwargs)
#     411
#     412     def _rewrite_membership_op(self, node, left, right):
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     399         method = "visit_" + type(node).__name__
#     400         visitor = getattr(self, method)
# --> 401         return visitor(node, **kwargs)
#     402
#     403     def visit_Module(self, node, **kwargs):
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/expr.py in visit_Compare(self, node, **kwargs)
#     708             op = self.translate_In(ops[0])
#     709             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 710             return self.visit(binop)
#     711
#     712         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     399         method = "visit_" + type(node).__name__
#     400         visitor = getattr(self, method)
# --> 401         return visitor(node, **kwargs)
#     402
#     403     def visit_Module(self, node, **kwargs):
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/expr.py in visit_BinOp(self, node, **kwargs)
#     520
#     521     def visit_BinOp(self, node, **kwargs):
# --> 522         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     523         left, right = self._maybe_downcast_constants(left, right)
#     524         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     440     def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     441         if left is None:
# --> 442             left = self.visit(node.left, side="left")
#     443         if right is None:
#     444             right = self.visit(node.right, side="right")
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     399         method = "visit_" + type(node).__name__
#     400         visitor = getattr(self, method)
# --> 401         return visitor(node, **kwargs)
#     402
#     403     def visit_Module(self, node, **kwargs):
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/expr.py in visit_Name(self, node, **kwargs)
#     533
#     534     def visit_Name(self, node, **kwargs):
# --> 535         return self.term_type(node.id, self.env, **kwargs)
#     536
#     537     def visit_NameConstant(self, node, **kwargs):
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/ops.py in __init__(self, name, env, side, encoding)
#      84         tname = str(name)
#      85         self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 86         self._value = self._resolve_name()
#      87         self.encoding = encoding
#      88
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/ops.py in _resolve_name(self)
#     101
#     102     def _resolve_name(self):
# --> 103         res = self.env.resolve(self.local_name, is_local=self.is_local)
#     104         self.update(res)
#     105
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     215                 from pandas.core.computation.ops import UndefinedVariableError
#     216
# --> 217                 raise UndefinedVariableError(key, is_local) from err
#     218
#     219     def swapkey(self, old_key: str, new_key: str, new_value=None):
#
# UndefinedVariableError: name 'oos_aov_initial_num' is not defined

# %%
aoi = get_initial_aov_goods_ratio(platforms, end_date - dt.timedelta(weeks = 2), end_date, oos_stores)

# %%
aof = get_aov_goods_ratio(platforms, end_date - dt.timedelta(weeks = 2), end_date, oos_stores)

# %%
nf = get_not_found_ratio(platforms, end_date - dt.timedelta(weeks = 2), end_date, oos_stores)

# %%
ct = get_collection_time_ratio(platforms, end_date - dt.timedelta(weeks = 2), end_date, oos_stores)

# %%
aof.query('anonymous_id == "056f9ad467c29f42"')
# Out:
#        platform      anonymous_id order_number        goods
# 397153  android  056f9ad467c29f42   R086115625  3039.620117

# %%
aoi.query('anonymous_id == "056f9ad467c29f42"')
# Out:
# Empty DataFrame
# Columns: [platform, anonymous_id, order_number, oos_aov_initial_num]
# Index: []

# %%
read_sql_query("""
SELECT *
  FROM shipments
 WHERE order_number = 'R086115625'
""")
# Out:
#   shipment_number order_number  shipment_id   order_id shipment_state  \
# 0    H40289121689   R086115625    316833697  253063671        shipped
#
#   order_state order_payment_state driver_login                driver_name  \
# 0    complete                paid   9996362082  Першина Ксения Михайловна
#
#   driver_phone shopper_login           shopper_name shopper_phone  store_id  \
# 0  79384117066  222409044305  Левина Инна Андреевна   79282478506       251
#
#    retailer_id   item_total  promo_total  total_cost        total  \
# 0           15  3039.620117          0.0         0.0  3039.620117
#
#            shipped_at  item_count  total_quantity  total_weight  \
# 0 2023-08-14 11:25:03           1              38         15960
#
#             starts_at  shipping_category_id             ends_at  \
# 0 2023-08-14 10:30:00                     2 2023-08-14 17:00:00
#
#          completed_at          created_at   tenant_id shipping_method_kind  \
# 0 2023-08-14 09:30:44 2022-12-15 11:00:45  sbermarket               pickup
#
#   retailer_name  b2b company_document_id  \
# 0          АШАН    0                None
#
#                                store_name  city_id  city_name  receipt_total  \
# 0  АШАН, Краснодар, улица Уральская, 79 .        9  Краснодар    3039.620117
#
#   fiscal_checksum  receipts_count       first_paid_at   user_id  \
# 0      2424485804               1 2023-08-14 13:08:00  15331402
#
#                  phone new_or_repeated cohort_tenant  delivery_window_id  \
# 0  2950132536493270676        repeated        auchan           277452504
#
#    ship_address_id  api_client_id                                  uuid  \
# 0        133863773             10  469e87a8-c2ea-4ba0-9339-310c7b3a61b6
#
#   company_name company_inn  weight_over_base  nominal_cost  owner_id  \
# 0                                        0.0           0.0  15331402
#
#     owner_type import_key  b2b_order_company_flg payment_method_name  \
# 0  Spree::User      10-21                      0       Картой онлайн
#
#    replaced_items_cnt  canceled_items_cnt  client_identifier device_type  \
# 0                   0                   0  SbermarketAndroid      mobile
#
#         os platform promo_code promo_type  shopper_call_flg  courier_call_flg  \
# 0  android      app         []         []                 0                 0
#
#    prev_delivery_window_id  store_express_delivery_flg  \
# 0                        0                           0
#
#    on_demand_delivery_flg  rate comment  delivery_area_id  base_store_id  \
# 0                       0   5.0                      4113            251
#
#   retailer_size             division_manager               city_manager  \
# 0   hypermarket  Лукомский Олег Владимирович  Джанхот Маргарита Алиевна
#
#                supervisor  address_latitude  address_longitude  prime_flg  \
# 0  Нархова Елена Ивановна         45.025288          39.108463          1
#
#   external_service_state external_id  b2b_measure  external_assembly_kind  \
# 0                   None        None            0                       0
#
#    orders_api_integration_type  payment_id  is_pharmacy_flg type_delivery  \
# 0                            0   159488704                0        pickup
#
#   type_store_delivery prime_lvl  cost invoice_number  invoice_total  \
# 0             planned    prime+   0.0           None            0.0
#
#                 zone_name  zone_id  retailer_discount_item_total  \
# 0  ЗОНА Г-Ашан, Уральская     5372                           0.0
#
#   loyal_user_flg  assembly_rate  shipping_rate retailer_category_name  \
# 0      not_loyal              5              0       Продукты питания
#
#   integration_type delivery_window_created_at
# 0        universal        2023-08-07 23:03:22

# %%
read_sql_query("""
SELECT *
  FROM line_items
 WHERE order_number = 'R086115625'
   AND toDate(order_completed_at) = toDate('2023-08-14')
""")
# Out:
#    line_item_id     offer_id       price  retailer_shelf_price  cost_price  \
# 0    2799640070  22652954484  345.989990            345.989990  345.989990
# 1    2694598489   1658494566  176.990005            176.990005  176.990005
#
#    vat_rate  quantity found_quantity  discount   order_id  shipment_id  \
# 0        20         1           None       0.0  253063671    316833697
# 1        20         1           None       0.0  253063671    316833697
#
#     tenant_id  store_id       city  order_completed_at shipment_shipped_at  \
# 0  sbermarket       251  Краснодар 2023-08-14 09:30:44 2023-08-14 11:25:03
# 1  sbermarket       251  Краснодар 2023-08-14 09:30:44 2023-08-14 11:25:03
#
#   order_state shipment_state  product_id  \
# 0    complete        shipped    27297833
# 1    complete        shipped     5074492
#
#                                         product_name  brand_id  \
# 0  Наполнитель для кошачьего туалета АШАН Красная...      8261
# 1  Конфеты Raffaello с цельным миндальным орехом ...      2119
#
#            brand_name        manufacturer  manufacturer_id retailer_sku  \
# 0  АШАН Красная птица          Лидинг ООО             6482       842656
# 1           Raffaello  Ферреро Руссия ЗАО             5940       882974
#
#   assembly_issue       li_created_at       li_deleted_at  b2b retailer_name  \
# 0           None 2023-05-31 10:15:15 2023-08-14 09:04:39    0          АШАН
# 1           None 2023-05-04 11:55:47 2023-05-04 11:56:50    0          АШАН
#
#    retailer_id   user_id                      master_category  \
# 0           15  15331402                          Наполнители
# 1           15  15331402  Конфеты и сладкие подарочные наборы
#
#    master_category_id  parent_category_id  \
# 0                1053                1050
# 1                  61                  56
#
#                                    uuid       sku order_number
# 0  0d641a39-216d-4b0e-adba-1db77ab241f5  15276586   R086115625
# 1  169f8326-71c0-4df3-aaf4-d734eb7d05cc    139256   R086115625

# %%
# Проверям пустые чеки (итоговые)

# %%
final_data['2w'].query('goods != goods')
# Out:
#                                  anonymous_id platform  not_found  \
# 56       000682bf-b846-4ae8-b700-8a989d379315      web        2.0
# 62                           00076b82cdc0c5e2  android        0.0
# 70                           0008793fa71e4e08  android        0.0
# 88                           000a509ab59f8de0  android        1.0
# 111                          000c445d2838af2b  android        2.0
# ...                                       ...      ...        ...
# 1877432                      006e1965b648a12f  android        NaN
# 1877433  274d524f-d81f-47d8-903d-5363188384ff      web        NaN
# 1877434  59ca33cd-33f1-478f-8ced-87e9ceae7f54      web        NaN
# 1877435                      b8f428d25e3000fa  android        NaN
# 1877436  5e54a556-f4b2-4fcc-837f-b27462569cd4      web        NaN
#
#          total_items  assembly_speed_positions_num  n_shipments  goods  \
# 56              18.0                        1233.5          1.0    NaN
# 62               9.0                         899.5          1.0    NaN
# 70              26.0                        2070.0          1.0    NaN
# 88             101.0                       11335.5         11.0    NaN
# 111             23.0                        2051.0          1.0    NaN
# ...              ...                           ...          ...    ...
# 1877432          NaN                           NaN          NaN    NaN
# 1877433          NaN                           NaN          NaN    NaN
# 1877434          NaN                           NaN          NaN    NaN
# 1877435          NaN                           NaN          NaN    NaN
# 1877436          NaN                           NaN          NaN    NaN
#
#          order_number_x  aov_initial_before  aov_initial_after  \
# 56                  NaN                 NaN                NaN
# 62                  NaN                 NaN                NaN
# 70                  NaN                 NaN                NaN
# 88                  NaN                 NaN                NaN
# 111                 NaN                 NaN                NaN
# ...                 ...                 ...                ...
# 1877432             NaN                 NaN                NaN
# 1877433             NaN                 NaN                NaN
# 1877434             NaN                 NaN                NaN
# 1877435             NaN                 NaN                NaN
# 1877436             NaN                 NaN                NaN
#
#          order_number_y      tenant  gmv_per_user_within_retilist  \
# 56                  NaN  sbermarket                           0.0
# 62                  NaN  sbermarket                           0.0
# 70                  NaN  sbermarket                           0.0
# 88                  NaN  sbermarket                           0.0
# 111                 NaN  sbermarket                           0.0
# ...                 ...         ...                           ...
# 1877432             NaN  sbermarket                           0.0
# 1877433             NaN  sbermarket                           0.0
# 1877434             NaN  sbermarket                           0.0
# 1877435             NaN  sbermarket                           0.0
# 1877436             NaN  sbermarket                           0.0
#
#          orders_within_retilist  conversion_within_retilist first_order_date  \
# 56                          0.0                         0.0             None
# 62                          0.0                         0.0             None
# 70                          0.0                         0.0             None
# 88                          0.0                         0.0             None
# 111                         0.0                         0.0             None
# ...                         ...                         ...              ...
# 1877432                     0.0                         0.0             None
# 1877433                     0.0                         0.0             None
# 1877434                     0.0                         0.0             None
# 1877435                     0.0                         0.0             None
# 1877436                     0.0                         0.0             None
#
#          ret_14d_within_retilist
# 56                           0.0
# 62                           0.0
# 70                           0.0
# 88                           0.0
# 111                          0.0
# ...                          ...
# 1877432                      0.0
# 1877433                      0.0
# 1877434                      0.0
# 1877435                      0.0
# 1877436                      0.0
#
# [1363537 rows x 17 columns]

# %%
nf.query('anonymous_id == "000a509ab59f8de0"')
# Out:
#        platform      anonymous_id order_number   order_id        completed_at  \
# 218518  android  000a509ab59f8de0   R345246042  349754810 2023-08-08 14:01:46
# 220274  android  000a509ab59f8de0   R754514567  353835672 2023-08-21 04:40:37
# 220275  android  000a509ab59f8de0   R837783041  354001854 2023-08-21 04:41:22
# 235832  android  000a509ab59f8de0   R553763856  352009394 2023-08-19 06:56:03
# 252947  android  000a509ab59f8de0   R765123067  350802793 2023-08-11 04:35:20
# 252948  android  000a509ab59f8de0   R741020041  350877291 2023-08-11 04:38:53
# 252949  android  000a509ab59f8de0   R017004467  350877956 2023-08-11 06:32:16
# 254813  android  000a509ab59f8de0   R463530013  350905937 2023-08-13 15:30:40
# 484669  android  000a509ab59f8de0   R766121107  351745883 2023-08-14 14:14:40
# 557543  android  000a509ab59f8de0   R328428704  353834252 2023-08-20 11:59:54
#
#         total_items  repl  canc  not_found    rc_rate
# 218518            2     0     0          0   0.000000
# 220274            4     0     0          0   0.000000
# 220275           15     0     0          0   0.000000
# 235832           20     2     0          2  10.000000
# 252947           15     0     0          0   0.000000
# 252948            3     0     0          0   0.000000
# 252949           40     3     1          4   9.756098
# 254813           27     0     1          1   3.571429
# 484669           13     1     0          1   7.692308
# 557543            1     0     0          0   0.000000

# %%
read_sql_query("""
SELECT owner_type,*
  FROM shipments
 WHERE order_number = 'R345246042'
""")
# Out:
#     owner_type shipment_number order_number  shipment_id   order_id  \
# 0  Spree::User    H31353796589   R345246042    429325988  349754810
#
#   shipment_state order_state order_payment_state  driver_login  \
# 0        shipped    complete                paid  342603685224
#
#              driver_name driver_phone shopper_login              shopper_name  \
# 0  Новиков Олег Игоревич  79220423079  341600497703  Сафонова Надежда Юрьевна
#
#   shopper_phone  store_id  retailer_id   item_total  promo_total  total_cost  \
# 0   79047554738       107            1  1013.909973          0.0        59.0
#
#          total          shipped_at  item_count  total_quantity  total_weight  \
# 0  1072.910034 2023-08-08 16:40:59           2               4          3630
#
#             starts_at  shipping_category_id             ends_at  \
# 0 2023-08-08 15:00:00                     2 2023-08-08 18:00:00
#
#          completed_at          created_at   tenant_id shipping_method_kind  \
# 0 2023-08-08 14:01:46 2023-08-07 10:26:32  sbermarket           by_courier
#
#   retailer_name  b2b company_document_id  \
# 0         METRO    1                None
#
#                                store_name  city_id  city_name  receipt_total  \
# 0  METRO, Волгоград, Историческая ул. 164       12  Волгоград            0.0
#
#   fiscal_checksum  receipts_count first_paid_at  user_id                phone  \
# 0            None               0          None  1940749  5651203267827947780
#
#   new_or_repeated cohort_tenant  delivery_window_id  ship_address_id  \
# 0        repeated    sbermarket           274008803        208462832
#
#    api_client_id                                  uuid company_name  \
# 0             10  4579c507-7b45-48ef-9750-4bbf9586a926
#
#   company_inn  weight_over_base  nominal_cost  owner_id   owner_type  \
# 0                           0.0         229.0   1940749  Spree::User
#
#   import_key  b2b_order_company_flg payment_method_name  replaced_items_cnt  \
# 0       1-28                      0       Картой онлайн                   0
#
#    canceled_items_cnt  client_identifier device_type       os platform  \
# 0                   0  SbermarketAndroid      mobile  android      app
#
#   promo_code promo_type  shopper_call_flg  courier_call_flg  \
# 0         []         []                 0                 0
#
#    prev_delivery_window_id  store_express_delivery_flg  \
# 0                        0                           0
#
#    on_demand_delivery_flg  rate comment  delivery_area_id  base_store_id  \
# 0                       0   0.0                         0              0
#
#   retailer_size          division_manager                  city_manager  \
# 0   hypermarket  Синчугов Иван Алексеевич  Треножкин Дмитрий Викторович
#
#                   supervisor  address_latitude  address_longitude  prime_flg  \
# 0  Храмов Аркадий Викторович         48.729786            44.5252          1
#
#   external_service_state external_id  b2b_measure  external_assembly_kind  \
# 0                   None        None            2                       0
#
#    orders_api_integration_type  payment_id  is_pharmacy_flg type_delivery  \
# 0                            0   157843931                0       planned
#
#   type_store_delivery prime_lvl  cost   invoice_number  invoice_total  \
# 0             planned    prime+  59.0  0/0/0094/050631     874.530029
#
#               zone_name  zone_id  retailer_discount_item_total loyal_user_flg  \
# 0  Историческая Метро К    12738                         56.91        no_info
#
#    assembly_rate  shipping_rate retailer_category_name integration_type  \
# 0              0              0       Продукты питания        universal
#
#   delivery_window_created_at
# 0        2023-08-01 23:01:37

# %%
read_sql_query("""
SELECT b2b_order_company_flg, b2b_measure
  FROM financial_measures
 WHERE order_number = 'R345246042'
""")
# Out:
#    b2b_order_company_flg  b2b_measure
# 0                      0            2

# %%
# Проверям пустое время сборки

# %%
final_data['2w'].query('assembly_speed_positions_num != assembly_speed_positions_num')
# Out:
#                                 anonymous_id platform  not_found  total_items  \
# 3                           00010adb4bbc712c  android        0.0         22.0
# 24                          00053fbdd166e105  android        0.0         96.0
# 30                          000611cda706943d  android        0.0          7.0
# 37                          000755ec3f765b50  android        0.0          9.0
# 38                          00075951e01323ab  android        0.0          8.0
# ...                                      ...      ...        ...          ...
# 460079                      ffffdcfecfa9e7f6  android        0.0          6.0
# 460142                      270017ce6b507db6  android        NaN          NaN
# 460143  67d02803-437e-4f48-9fb8-286d6ffd94f9      web        NaN          NaN
# 460144                      783f9a7dba591329  android        NaN          NaN
# 460145                      8dea89b247ca6922  android        NaN          NaN
#
#         assembly_speed_positions_num  n_shipments         goods  \
# 3                                NaN          NaN   3125.300049
# 24                               NaN          NaN  11565.059814
# 30                               NaN          NaN    720.429993
# 37                               NaN          NaN   1589.880005
# 38                               NaN          NaN    942.099976
# ...                              ...          ...           ...
# 460079                           NaN          NaN   1394.869995
# 460142                           NaN          NaN           NaN
# 460143                           NaN          NaN           NaN
# 460144                           NaN          NaN           NaN
# 460145                           NaN          NaN           NaN
#
#         order_number_x  oos_aov_initial_num  order_number_y
# 3                  2.0          3125.299974             2.0
# 24                 3.0         11565.060116             3.0
# 30                 1.0           720.430016             1.0
# 37                 1.0          1589.880013             1.0
# 38                 1.0           942.100014             1.0
# ...                ...                  ...             ...
# 460079             2.0          1394.870014             2.0
# 460142             NaN          3812.059988             1.0
# 460143             NaN           519.000000             1.0
# 460144             NaN         26997.000000             1.0
# 460145             NaN          1141.020012             1.0
#
# [49721 rows x 10 columns]

# %%
nf.query('anonymous_id == "00010adb4bbc712c"')
# Out:
#        platform      anonymous_id order_number   order_id        completed_at  \
# 18512   android  00010adb4bbc712c   R484810503  350034006 2023-08-13 10:41:40
# 308741  android  00010adb4bbc712c   R813060778  351646601 2023-08-18 09:51:39
#
#         total_items  repl  canc  not_found  rc_rate
# 18512            10     0     0          0      0.0
# 308741           12     0     0          0      0.0

# %%
read_sql_query("""
SELECT shipment_number, shipped_at FROM shipments where order_number IN ('R484810503','R813060778')
""")
# Out:
#   shipment_number          shipped_at
# 0    H71808562601 2023-08-13 11:25:35
# 1    H94553473094 2023-08-18 10:26:14

# %%
read_sql_query("""
select toDate(shipped_at) as Date, 
           store_id as store_id_click, 
           start_assembling_to_first_item * ifNull(start_to_first_item_coef, 1)   
               + items_collection_time * ifNull(items_collection_time_coef, 1)                            
               + last_item_to_cashing_started * ifNull(last_item_to_cashing_coef, 1) as assembly_speed_positions_num 
    from sandbox.cte_decomposition_new
    where toDate(shipped_at) >= toDate('{date_from}') 
    and toDate(shipped_at) <= toDate('{date_to}')
    and overall_time_of_order is not null
    фтв
""")

# %%
read_sql_query("""
SELECT toDate(shipped_at) as Date, 
           store_id as store_id_click, 
           start_assembling_to_first_item * ifNull(start_to_first_item_coef, 1)   
               + items_collection_time * ifNull(items_collection_time_coef, 1)                            
               + last_item_to_cashing_started * ifNull(last_item_to_cashing_coef, 1) as assembly_speed_positions_num 
  FROM sandbox.cte_decomposition_new 
 where shipment_number in ('H71808562601','H94553473094') 
   AND toDate(shipped_at) IN (toDate('2023-08-13'),toDate('2023-08-18'))
 limit 10""")
# Out:
#          Date  store_id_click assembly_speed_positions_num
# 0  2023-08-18           33860                         None
# 1  2023-08-13           31354                         None

# %% [markdown]
# ## MDE_estimation

# %%
res = {"platform": [], 
       "length": [], 
       "traffic_proportion": [], 
       "alpha":[], 
       "nobs":[],
       "est":[],
       "mde_abs": [], 
       "mde_percent": [],
       "metric": []
      }

# %%
# data = {f'{i+min(lengths)}w':old_data[j] for i,j in enumerate(old_data.keys())}
data = final_data.copy()

# %%
# format: (num, denum), if denum is None => average metric
metrics = [
    ("not_found", "total_items"),
    ("assembly_speed_positions_num", "n_shipments"),
    ("goods", "order_number_x"),
    ("aov_initial_before", "order_number_y"),
    ("aov_initial_after", "order_number_y"),
    ("ret_14d_within_retilist", None)
]

# %%
ratio = 1
power = 0.8

for platform in platforms:
    for length in data.keys():
        for traffic_proportion in traffic_proportions:
            for metric in tqdm(metrics):
                df = data[length].loc[data[length]["platform"]==platform].sample(frac=traffic_proportion)
                num_col = metric[0]
                denum_col = metric[1]
                
                if num_col == "gmv_per_user" and denum_col == "order_count": # aov preprocessing
                    df = df[df["order_count"]>0]
                if num_col == "assembly_speed_positions_num" and denum_col == "n_shipments": # aov preprocessing
                    df = df[df["n_shipments"]>0]
                if num_col == "not_found" and denum_col == "total_items": # aov preprocessing
                    df = df[df["total_items"]>0]
                if num_col == "goods" and denum_col == "order_number_x": # aov preprocessing
                    df = df[df["order_number_x"]>0]
                if num_col == "aov_initial_before" and denum_col == "order_number_y": # aov preprocessing
                    df = df[df["order_number_y"]>0]
                if num_col == "aov_initial_after" and denum_col == "order_number_y": # aov preprocessing
                    df = df[df["order_number_y"]>0]
                if num_col == "ret_14d_within_retilist": # aov preprocessing
                    df = df[df["ret_14d_within_retilist"]==df["ret_14d_within_retilist"]]                    
                    
                df = df.sample(frac=0.5) # select one group
                
                if denum_col:
                    num = df[num_col]
                    denum = df[denum_col]
                    est, sd = deltamethod(denum, num, independent=False, bc=True)
                else:
                    est = df[num_col].mean()
                    sd = df[num_col].std()
                
                nobs_test = df[num_col].shape[0]
                
                for threshold in thresholds:
                    alpha = threshold
                    effect_size =  tt_ind_solve_power(power=power, nobs1=nobs_test, alpha=alpha, ratio=ratio)
                    mde_percent = effect_size*sd/est
                    mde_abs = mde_percent*est
                    res["platform"].append(platform)
                    res["length"].append(length)
                    res["traffic_proportion"].append(traffic_proportion)
                    res["alpha"].append(alpha)
                    res["nobs"].append(nobs_test)
                    res["est"].append(est)
                    res["mde_abs"].append(mde_abs)
                    res["mde_percent"].append(mde_percent)
                    res["metric"].append(metric)
# Out:
# 100%|██████████| 6/6 [00:03<00:00,  1.53it/s]
# 100%|██████████| 6/6 [00:04<00:00,  1.21it/s]
# 100%|██████████| 6/6 [00:07<00:00,  1.21s/it]
# 100%|██████████| 6/6 [00:10<00:00,  1.68s/it]
# 100%|██████████| 6/6 [00:12<00:00,  2.07s/it]
# 100%|██████████| 6/6 [00:04<00:00,  1.30it/s]
# 100%|██████████| 6/6 [00:06<00:00,  1.00s/it]
# 100%|██████████| 6/6 [00:09<00:00,  1.53s/it]
# 100%|██████████| 6/6 [00:12<00:00,  2.07s/it]
# 100%|██████████| 6/6 [00:16<00:00,  2.79s/it]
# 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# 100%|██████████| 6/6 [00:07<00:00,  1.29s/it]
# 100%|██████████| 6/6 [00:11<00:00,  1.97s/it]
# 100%|██████████| 6/6 [00:15<00:00,  2.55s/it]
# 100%|██████████| 6/6 [00:20<00:00,  3.46s/it]
# 100%|██████████| 6/6 [00:01<00:00,  3.18it/s]
# 100%|██████████| 6/6 [00:02<00:00,  2.73it/s]
# 100%|██████████| 6/6 [00:02<00:00,  2.20it/s]
# 100%|██████████| 6/6 [00:03<00:00,  1.78it/s]
# 100%|██████████| 6/6 [00:03<00:00,  1.58it/s]
# 100%|██████████| 6/6 [00:02<00:00,  2.67it/s]
# 100%|██████████| 6/6 [00:02<00:00,  2.10it/s]
# 100%|██████████| 6/6 [00:03<00:00,  1.67it/s]
# 100%|██████████| 6/6 [00:04<00:00,  1.37it/s]
# 100%|██████████| 6/6 [00:05<00:00,  1.17it/s]
# 100%|██████████| 6/6 [00:02<00:00,  2.22it/s]
# 100%|██████████| 6/6 [00:03<00:00,  1.82it/s]
# 100%|██████████| 6/6 [00:04<00:00,  1.40it/s]
# 100%|██████████| 6/6 [00:05<00:00,  1.10it/s]
# 100%|██████████| 6/6 [00:06<00:00,  1.14s/it]

# %%
res.keys()
# Out:
# dict_keys(['platform', 'length', 'traffic_proportion', 'alpha', 'nobs', 'est', 'mde_abs', 'mde_percent', 'metric'])

# %%
mde_df = pd.DataFrame(res)
mde_df["mde_abs"] = mde_df["mde_abs"].round(4)
mde_df["mde_percent"] = (mde_df["mde_percent"]*100).round(2).astype(str) + "%"
# mde_df["metric"] = mde_df["metric"].astype(str).replace(metric_names)

# %%
(
    mde_df
    .query('alpha == 0.05')
    .query('traffic_proportion == 1')
    .sort_values(by = ['metric','platform','length'])
)
# Out:
#     platform length  traffic_proportion  alpha    nobs          est   mde_abs  \
# 56   android     2w                 1.0   0.05  225132  2492.287723   18.6968
# 116  android     3w                 1.0   0.05  283919  2490.515726   16.4591
# 176  android     4w                 1.0   0.05  334592  2517.113628   15.5559
# 236      web     2w                 1.0   0.05   31826  2886.240884   70.0084
# 296      web     3w                 1.0   0.05   42718  2852.414550   55.3826
# 356      web     4w                 1.0   0.05   53576  2852.771036   48.3469
# 54   android     2w                 1.0   0.05  225132  2669.791938   41.9773
# 114  android     3w                 1.0   0.05  283919  2657.210199   32.8805
# 174  android     4w                 1.0   0.05  334592  2684.785728   22.7306
# 234      web     2w                 1.0   0.05   31826  3090.028753  173.0836
# 294      web     3w                 1.0   0.05   42718  3117.899833  172.5608
# 354      web     4w                 1.0   0.05   53576  3066.389657   66.9832
# 50   android     2w                 1.0   0.05  174819  1442.423544   11.4996
# 110  android     3w                 1.0   0.05  223113  1467.922176   10.9769
# 170  android     4w                 1.0   0.05  265916  1487.196298   10.1968
# 230      web     2w                 1.0   0.05   29737  1414.388899   39.5830
# 290      web     3w                 1.0   0.05   40003  1442.141501   39.9789
# 350      web     4w                 1.0   0.05   50136  1459.245529   41.0555
# 52   android     2w                 1.0   0.05  225136  2493.518007   18.3960
# 112  android     3w                 1.0   0.05  283924  2487.216821   17.3259
# 172  android     4w                 1.0   0.05  334600  2515.304213   15.4182
# 232      web     2w                 1.0   0.05   31814  2873.519674   66.3287
# 292      web     3w                 1.0   0.05   42702  2854.898265   57.7725
# 352      web     4w                 1.0   0.05   53559  2867.441749   48.6930
# 48   android     2w                 1.0   0.05  230088     0.059403    0.0006
# 108  android     3w                 1.0   0.05  290048     0.059069    0.0005
# 168  android     4w                 1.0   0.05  341741     0.058791    0.0005
# 228      web     2w                 1.0   0.05   34047     0.060501    0.0017
# 288      web     3w                 1.0   0.05   45686     0.059428    0.0015
# 348      web     4w                 1.0   0.05   57238     0.059229    0.0014
# 58   android     2w                 1.0   0.05  690812     0.156459    0.0017
# 118  android     3w                 1.0   0.05  840652     0.172530    0.0016
# 178  android     4w                 1.0   0.05  972131     0.180234    0.0015
# 238      web     2w                 1.0   0.05  245537     0.060451    0.0019
# 298      web     3w                 1.0   0.05  326958     0.063403    0.0017
# 358      web     4w                 1.0   0.05  401648     0.067233    0.0016
#
#     mde_percent                                       metric
# 56        0.75%          (aov_initial_after, order_number_y)
# 116       0.66%          (aov_initial_after, order_number_y)
# 176       0.62%          (aov_initial_after, order_number_y)
# 236       2.43%          (aov_initial_after, order_number_y)
# 296       1.94%          (aov_initial_after, order_number_y)
# 356       1.69%          (aov_initial_after, order_number_y)
# 54        1.57%         (aov_initial_before, order_number_y)
# 114       1.24%         (aov_initial_before, order_number_y)
# 174       0.85%         (aov_initial_before, order_number_y)
# 234        5.6%         (aov_initial_before, order_number_y)
# 294       5.53%         (aov_initial_before, order_number_y)
# 354       2.18%         (aov_initial_before, order_number_y)
# 50         0.8%  (assembly_speed_positions_num, n_shipments)
# 110       0.75%  (assembly_speed_positions_num, n_shipments)
# 170       0.69%  (assembly_speed_positions_num, n_shipments)
# 230        2.8%  (assembly_speed_positions_num, n_shipments)
# 290       2.77%  (assembly_speed_positions_num, n_shipments)
# 350       2.81%  (assembly_speed_positions_num, n_shipments)
# 52        0.74%                      (goods, order_number_x)
# 112        0.7%                      (goods, order_number_x)
# 172       0.61%                      (goods, order_number_x)
# 232       2.31%                      (goods, order_number_x)
# 292       2.02%                      (goods, order_number_x)
# 352        1.7%                      (goods, order_number_x)
# 48         1.0%                     (not_found, total_items)
# 108       0.85%                     (not_found, total_items)
# 168       0.82%                     (not_found, total_items)
# 228       2.81%                     (not_found, total_items)
# 288       2.51%                     (not_found, total_items)
# 348       2.32%                     (not_found, total_items)
# 58        1.11%              (ret_14d_within_retilist, None)
# 118       0.95%              (ret_14d_within_retilist, None)
# 178       0.86%              (ret_14d_within_retilist, None)
# 238       3.15%              (ret_14d_within_retilist, None)
# 298       2.66%              (ret_14d_within_retilist, None)
# 358       2.33%              (ret_14d_within_retilist, None)

# %%
mde_df.reset_index(drop=True).assign(metric = lambda _df: _df.metric.astype(str)).to_feather('mde_df.feather')

# %%
mde_df
# Out:
#     platform length  traffic_proportion  alpha    nobs          est  mde_abs  \
# 0    android     2w               0.125   0.05   28720     0.060070   0.0016
# 1    android     2w               0.125   0.01   28720     0.060070   0.0020
# 2    android     2w               0.125   0.05   21921  1445.594640  33.0128
# 3    android     2w               0.125   0.01   21921  1445.594640  40.2730
# 4    android     2w               0.125   0.05   27906  2497.876223  48.9896
# ..       ...    ...                 ...    ...     ...          ...      ...
# 355      web     4w               1.000   0.01   53576  3066.389657  81.7145
# 356      web     4w               1.000   0.05   53576  2852.771036  48.3469
# 357      web     4w               1.000   0.01   53576  2852.771036  58.9796
# 358      web     4w               1.000   0.05  401648     0.067233   0.0016
# 359      web     4w               1.000   0.01  401648     0.067233   0.0019
#
#     mde_percent                                       metric
# 0         2.69%                     (not_found, total_items)
# 1         3.28%                     (not_found, total_items)
# 2         2.28%  (assembly_speed_positions_num, n_shipments)
# 3         2.79%  (assembly_speed_positions_num, n_shipments)
# 4         1.96%                      (goods, order_number_x)
# ..          ...                                          ...
# 355       2.66%         (aov_initial_before, order_number_y)
# 356       1.69%          (aov_initial_after, order_number_y)
# 357       2.07%          (aov_initial_after, order_number_y)
# 358       2.33%              (ret_14d_within_retilist, None)
# 359       2.84%              (ret_14d_within_retilist, None)
#
# [360 rows x 9 columns]

# %%
metric_names = dict.fromkeys(mde_df.metric.astype(str).unique())
metric_names
# Out:
# {"('not_found', 'total_items')": None,
#  "('assembly_speed_positions_num', 'n_shipments')": None,
#  "('goods', 'order_number_x')": None,
#  "('aov_initial_before', 'order_number_y')": None,
#  "('aov_initial_after', 'order_number_y')": None,
#  "('ret_14d_within_retilist', None)": None}

# %%
metric_names = \
{"('not_found', 'total_items')": "Доля отмен/замен",
 "('assembly_speed_positions_num', 'n_shipments')": "Среднее время сборки",
 "('goods', 'order_number_x')": "Средний чек",
 "('aov_initial_before', 'order_number_y')": "Средний чек по line_items (до)",
 "('aov_initial_after', 'order_number_y')": "Средний чек по line_items (после)",
 "('ret_14d_within_retilist', None)": "Ретеншн 14д"}

# %%
print((
    mde_df
    .assign(metric_name = lambda _df: _df.metric.astype(str).replace(metric_names))
).to_markdown(index=False))
# Out:
# | platform   | length   |   traffic_proportion |   alpha |   nobs |          est |   mde_abs | mde_percent   | metric                                          | metric_name                       |
# |:-----------|:---------|---------------------:|--------:|-------:|-------------:|----------:|:--------------|:------------------------------------------------|:----------------------------------|
# | android    | 2w       |                0.125 |    0.05 |  28720 |    0.0600704 |    0.0016 | 2.69%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 2w       |                0.125 |    0.01 |  28720 |    0.0600704 |    0.002  | 3.28%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 2w       |                0.125 |    0.05 |  21921 | 1445.59      |   33.0128 | 2.28%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 2w       |                0.125 |    0.01 |  21921 | 1445.59      |   40.273  | 2.79%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 2w       |                0.125 |    0.05 |  27906 | 2497.88      |   48.9896 | 1.96%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 2w       |                0.125 |    0.01 |  27906 | 2497.88      |   59.7642 | 2.39%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 2w       |                0.125 |    0.05 |  28126 | 2719.09      |  273.792  | 10.07%        | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 2w       |                0.125 |    0.01 |  28126 | 2719.09      |  334.019  | 12.28%        | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 2w       |                0.125 |    0.05 |  28174 | 2496.4       |   49.1822 | 1.97%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 2w       |                0.125 |    0.01 |  28174 | 2496.4       |   60.0008 | 2.4%          | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 2w       |                0.125 |    0.05 |  86352 |    0.157958  |    0.0049 | 3.11%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 2w       |                0.125 |    0.01 |  86352 |    0.157958  |    0.006  | 3.8%          | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 2w       |                0.25  |    0.05 |  57566 |    0.0592679 |    0.0011 | 1.93%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 2w       |                0.25  |    0.01 |  57566 |    0.0592679 |    0.0014 | 2.35%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 2w       |                0.25  |    0.05 |  43711 | 1442.4       |   22.4143 | 1.55%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 2w       |                0.25  |    0.01 |  43711 | 1442.4       |   27.3449 | 1.9%          | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 2w       |                0.25  |    0.05 |  56240 | 2506.66      |   36.7387 | 1.47%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 2w       |                0.25  |    0.01 |  56240 | 2506.66      |   44.8088 | 1.79%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 2w       |                0.25  |    0.05 |  56368 | 2656.14      |   44.8537 | 1.69%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 2w       |                0.25  |    0.01 |  56368 | 2656.14      |   54.7066 | 2.06%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 2w       |                0.25  |    0.05 |  56292 | 2496.49      |   36.3291 | 1.46%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 2w       |                0.25  |    0.01 |  56292 | 2496.49      |   44.3093 | 1.77%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 2w       |                0.25  |    0.05 | 172703 |    0.157079  |    0.0035 | 2.21%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 2w       |                0.25  |    0.01 | 172703 |    0.157079  |    0.0042 | 2.69%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 2w       |                0.5   |    0.05 | 115159 |    0.0594747 |    0.0009 | 1.45%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 2w       |                0.5   |    0.01 | 115159 |    0.0594747 |    0.0011 | 1.77%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 2w       |                0.5   |    0.05 |  87347 | 1440.53      |   15.8873 | 1.1%          | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 2w       |                0.5   |    0.01 |  87347 | 1440.53      |   19.3813 | 1.35%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 2w       |                0.5   |    0.05 | 112518 | 2501.77      |   25.8999 | 1.04%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 2w       |                0.5   |    0.01 | 112518 | 2501.77      |   31.5969 | 1.26%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 2w       |                0.5   |    0.05 | 112474 | 2672.22      |   74.2865 | 2.78%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 2w       |                0.5   |    0.01 | 112474 | 2672.22      |   90.6265 | 3.39%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 2w       |                0.5   |    0.05 | 112600 | 2510.18      |   26.1543 | 1.04%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 2w       |                0.5   |    0.01 | 112600 | 2510.18      |   31.9102 | 1.27%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 2w       |                0.5   |    0.05 | 345406 |    0.156723  |    0.0025 | 1.56%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 2w       |                0.5   |    0.01 | 345406 |    0.156723  |    0.003  | 1.91%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 2w       |                0.75  |    0.05 | 172380 |    0.0593665 |    0.0007 | 1.12%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 2w       |                0.75  |    0.01 | 172380 |    0.0593665 |    0.0008 | 1.37%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 2w       |                0.75  |    0.05 | 131073 | 1442.98      |   13.2748 | 0.92%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 2w       |                0.75  |    0.01 | 131073 | 1442.98      |   16.1894 | 1.12%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 2w       |                0.75  |    0.05 | 168748 | 2499.05      |   21.8531 | 0.87%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 2w       |                0.75  |    0.01 | 168748 | 2499.05      |   26.654  | 1.07%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 2w       |                0.75  |    0.05 | 168822 | 2655.19      |   27.3653 | 1.03%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 2w       |                0.75  |    0.01 | 168822 | 2655.19      |   33.3772 | 1.26%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 2w       |                0.75  |    0.05 | 168864 | 2497.65      |   21.0684 | 0.84%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 2w       |                0.75  |    0.01 | 168864 | 2497.65      |   25.6968 | 1.03%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 2w       |                0.75  |    0.05 | 518109 |    0.156432  |    0.002  | 1.28%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 2w       |                0.75  |    0.01 | 518109 |    0.156432  |    0.0024 | 1.56%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 2w       |                1     |    0.05 | 230088 |    0.059403  |    0.0006 | 1.0%          | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 2w       |                1     |    0.01 | 230088 |    0.059403  |    0.0007 | 1.21%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 2w       |                1     |    0.05 | 174819 | 1442.42      |   11.4996 | 0.8%          | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 2w       |                1     |    0.01 | 174819 | 1442.42      |   14.0254 | 0.97%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 2w       |                1     |    0.05 | 225136 | 2493.52      |   18.396  | 0.74%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 2w       |                1     |    0.01 | 225136 | 2493.52      |   22.4424 | 0.9%          | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 2w       |                1     |    0.05 | 225132 | 2669.79      |   41.9773 | 1.57%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 2w       |                1     |    0.01 | 225132 | 2669.79      |   51.2106 | 1.92%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 2w       |                1     |    0.05 | 225132 | 2492.29      |   18.6968 | 0.75%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 2w       |                1     |    0.01 | 225132 | 2492.29      |   22.8093 | 0.92%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 2w       |                1     |    0.05 | 690812 |    0.156459  |    0.0017 | 1.11%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 2w       |                1     |    0.01 | 690812 |    0.156459  |    0.0021 | 1.35%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 3w       |                0.125 |    0.05 |  36350 |    0.0591526 |    0.0014 | 2.31%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 3w       |                0.125 |    0.01 |  36350 |    0.0591526 |    0.0017 | 2.81%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 3w       |                0.125 |    0.05 |  27939 | 1468.89      |   30.6967 | 2.09%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 3w       |                0.125 |    0.01 |  27939 | 1468.89      |   37.4481 | 2.55%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 3w       |                0.125 |    0.05 |  35334 | 2483.66      |   45.6185 | 1.84%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 3w       |                0.125 |    0.01 |  35334 | 2483.66      |   55.6469 | 2.24%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 3w       |                0.125 |    0.05 |  35556 | 2719.32      |  201.635  | 7.41%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 3w       |                0.125 |    0.01 |  35556 | 2719.32      |  245.948  | 9.04%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 3w       |                0.125 |    0.05 |  35405 | 2495.43      |   44.6393 | 1.79%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 3w       |                0.125 |    0.01 |  35405 | 2495.43      |   54.4515 | 2.18%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 3w       |                0.125 |    0.05 | 105082 |    0.172161  |    0.0046 | 2.68%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 3w       |                0.125 |    0.01 | 105082 |    0.172161  |    0.0056 | 3.27%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 3w       |                0.25  |    0.05 |  72659 |    0.059267  |    0.001  | 1.65%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 3w       |                0.25  |    0.01 |  72659 |    0.059267  |    0.0012 | 2.01%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 3w       |                0.25  |    0.05 |  55827 | 1463.81      |   21.488  | 1.47%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 3w       |                0.25  |    0.01 |  55827 | 1463.81      |   26.2096 | 1.79%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 3w       |                0.25  |    0.05 |  70914 | 2479.79      |   33.0001 | 1.33%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 3w       |                0.25  |    0.01 |  70914 | 2479.79      |   40.264  | 1.62%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 3w       |                0.25  |    0.05 |  70998 | 2641.6       |   45.726  | 1.73%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 3w       |                0.25  |    0.01 |  70998 | 2641.6       |   55.7913 | 2.11%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 3w       |                0.25  |    0.05 |  71028 | 2485.6       |   31.7963 | 1.28%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 3w       |                0.25  |    0.01 |  71028 | 2485.6       |   38.7847 | 1.56%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 3w       |                0.25  |    0.05 | 210163 |    0.170867  |    0.0033 | 1.9%          | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 3w       |                0.25  |    0.01 | 210163 |    0.170867  |    0.004  | 2.32%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 3w       |                0.5   |    0.05 | 144858 |    0.0592056 |    0.0007 | 1.17%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 3w       |                0.5   |    0.01 | 144858 |    0.0592056 |    0.0008 | 1.42%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 3w       |                0.5   |    0.05 | 111496 | 1463.93      |   15.9422 | 1.09%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 3w       |                0.5   |    0.01 | 111496 | 1463.93      |   19.4483 | 1.33%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 3w       |                0.5   |    0.05 | 141776 | 2491.7       |   23.8429 | 0.96%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 3w       |                0.5   |    0.01 | 141776 | 2491.7       |   29.089  | 1.17%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 3w       |                0.5   |    0.05 | 142111 | 2658.94      |   35.3685 | 1.33%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 3w       |                0.5   |    0.01 | 142111 | 2658.94      |   43.1498 | 1.62%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 3w       |                0.5   |    0.05 | 141772 | 2488.35      |   24.7511 | 0.99%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 3w       |                0.5   |    0.01 | 141772 | 2488.35      |   30.1971 | 1.21%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 3w       |                0.5   |    0.05 | 420326 |    0.172273  |    0.0023 | 1.34%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 3w       |                0.5   |    0.01 | 420326 |    0.172273  |    0.0028 | 1.63%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 3w       |                0.75  |    0.05 | 217514 |    0.0588661 |    0.0006 | 1.07%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 3w       |                0.75  |    0.01 | 217514 |    0.0588661 |    0.0008 | 1.31%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 3w       |                0.75  |    0.05 | 167352 | 1461.36      |   12.4074 | 0.85%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 3w       |                0.75  |    0.01 | 167352 | 1461.36      |   15.1333 | 1.04%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 3w       |                0.75  |    0.05 | 213073 | 2489.8       |   20.0718 | 0.81%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 3w       |                0.75  |    0.01 | 213073 | 2489.8       |   24.4858 | 0.98%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 3w       |                0.75  |    0.05 | 212964 | 2662.94      |   41.0578 | 1.54%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 3w       |                0.75  |    0.01 | 212964 | 2662.94      |   50.0867 | 1.88%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 3w       |                0.75  |    0.05 | 213074 | 2493.49      |   19.9487 | 0.8%          | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 3w       |                0.75  |    0.01 | 213074 | 2493.49      |   24.3356 | 0.98%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 3w       |                0.75  |    0.05 | 630488 |    0.172341  |    0.0019 | 1.09%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 3w       |                0.75  |    0.01 | 630488 |    0.172341  |    0.0023 | 1.33%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 3w       |                1     |    0.05 | 290048 |    0.0590691 |    0.0005 | 0.85%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 3w       |                1     |    0.01 | 290048 |    0.0590691 |    0.0006 | 1.04%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 3w       |                1     |    0.05 | 223113 | 1467.92      |   10.9769 | 0.75%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 3w       |                1     |    0.01 | 223113 | 1467.92      |   13.392  | 0.91%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 3w       |                1     |    0.05 | 283924 | 2487.22      |   17.3259 | 0.7%          | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 3w       |                1     |    0.01 | 283924 | 2487.22      |   21.1325 | 0.85%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 3w       |                1     |    0.05 | 283919 | 2657.21      |   32.8805 | 1.24%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 3w       |                1     |    0.01 | 283919 | 2657.21      |   40.1045 | 1.51%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 3w       |                1     |    0.05 | 283919 | 2490.52      |   16.4591 | 0.66%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 3w       |                1     |    0.01 | 283919 | 2490.52      |   20.0753 | 0.81%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 3w       |                1     |    0.05 | 840652 |    0.17253   |    0.0016 | 0.95%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 3w       |                1     |    0.01 | 840652 |    0.17253   |    0.002  | 1.15%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 4w       |                0.125 |    0.05 |  42824 |    0.0592944 |    0.0013 | 2.12%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 4w       |                0.125 |    0.01 |  42824 |    0.0592944 |    0.0015 | 2.59%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 4w       |                0.125 |    0.05 |  33264 | 1489.63      |   27.3208 | 1.83%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 4w       |                0.125 |    0.01 |  33264 | 1489.63      |   33.3269 | 2.24%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 4w       |                0.125 |    0.05 |  41840 | 2516.49      |   46.8413 | 1.86%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 4w       |                0.125 |    0.01 |  41840 | 2516.49      |   57.1326 | 2.27%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 4w       |                0.125 |    0.05 |  41869 | 2651.11      |   49.8322 | 1.88%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 4w       |                0.125 |    0.01 |  41869 | 2651.11      |   60.7806 | 2.29%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 4w       |                0.125 |    0.05 |  41856 | 2524.19      |   44.324  | 1.76%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 4w       |                0.125 |    0.01 |  41856 | 2524.19      |   54.0623 | 2.14%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 4w       |                0.125 |    0.05 | 121516 |    0.17926   |    0.0044 | 2.43%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 4w       |                0.125 |    0.01 | 121516 |    0.17926   |    0.0053 | 2.97%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 4w       |                0.25  |    0.05 |  85453 |    0.0588448 |    0.0009 | 1.48%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 4w       |                0.25  |    0.01 |  85453 |    0.0588448 |    0.0011 | 1.8%          | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 4w       |                0.25  |    0.05 |  66490 | 1480.07      |   19.2864 | 1.3%          | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 4w       |                0.25  |    0.01 |  66490 | 1480.07      |   23.5264 | 1.59%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 4w       |                0.25  |    0.05 |  83606 | 2515.97      |   30.065  | 1.19%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 4w       |                0.25  |    0.01 |  83606 | 2515.97      |   36.6748 | 1.46%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 4w       |                0.25  |    0.05 |  83505 | 2706.38      |   45.6514 | 1.69%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 4w       |                0.25  |    0.01 |  83505 | 2706.38      |   55.688  | 2.06%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 4w       |                0.25  |    0.05 |  83356 | 2523.99      |   31.3994 | 1.24%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 4w       |                0.25  |    0.01 |  83356 | 2523.99      |   38.3027 | 1.52%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 4w       |                0.25  |    0.05 | 243033 |    0.179494  |    0.0031 | 1.72%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 4w       |                0.25  |    0.01 | 243033 |    0.179494  |    0.0038 | 2.1%          | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 4w       |                0.5   |    0.05 | 170832 |    0.0587545 |    0.0007 | 1.2%          | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 4w       |                0.5   |    0.01 | 170832 |    0.0587545 |    0.0009 | 1.46%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 4w       |                0.5   |    0.05 | 132850 | 1486.64      |   14.734  | 0.99%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 4w       |                0.5   |    0.01 | 132850 | 1486.64      |   17.9765 | 1.21%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 4w       |                0.5   |    0.05 | 167400 | 2522.15      |   21.5102 | 0.85%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 4w       |                0.5   |    0.01 | 167400 | 2522.15      |   26.236  | 1.04%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 4w       |                0.5   |    0.05 | 167285 | 2696.71      |   47.83   | 1.77%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 4w       |                0.5   |    0.01 | 167285 | 2696.71      |   58.3382 | 2.16%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 4w       |                0.5   |    0.05 | 167724 | 2517.58      |   21.9609 | 0.87%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 4w       |                0.5   |    0.01 | 167724 | 2517.58      |   26.7856 | 1.06%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 4w       |                0.5   |    0.05 | 486066 |    0.180434  |    0.0022 | 1.21%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 4w       |                0.5   |    0.01 | 486066 |    0.180434  |    0.0027 | 1.48%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 4w       |                0.75  |    0.05 | 256098 |    0.0589495 |    0.0005 | 0.89%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 4w       |                0.75  |    0.01 | 256098 |    0.0589495 |    0.0006 | 1.09%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 4w       |                0.75  |    0.05 | 199420 | 1487.81      |   12.0901 | 0.81%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 4w       |                0.75  |    0.01 | 199420 | 1487.81      |   14.7482 | 0.99%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 4w       |                0.75  |    0.05 | 250952 | 2519.85      |   18.0393 | 0.72%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 4w       |                0.75  |    0.01 | 250952 | 2519.85      |   22.0029 | 0.87%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 4w       |                0.75  |    0.05 | 250940 | 2698.93      |   36.8423 | 1.37%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 4w       |                0.75  |    0.01 | 250940 | 2698.93      |   44.9375 | 1.67%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 4w       |                0.75  |    0.05 | 250874 | 2515         |   18.264  | 0.73%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 4w       |                0.75  |    0.01 | 250874 | 2515         |   22.2771 | 0.89%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 4w       |                0.75  |    0.05 | 729098 |    0.180058  |    0.0018 | 0.99%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 4w       |                0.75  |    0.01 | 729098 |    0.180058  |    0.0022 | 1.21%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 4w       |                1     |    0.05 | 341741 |    0.0587906 |    0.0005 | 0.82%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 4w       |                1     |    0.01 | 341741 |    0.0587906 |    0.0006 | 0.99%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | android    | 4w       |                1     |    0.05 | 265916 | 1487.2       |   10.1968 | 0.69%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 4w       |                1     |    0.01 | 265916 | 1487.2       |   12.4343 | 0.84%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | android    | 4w       |                1     |    0.05 | 334600 | 2515.3       |   15.4182 | 0.61%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 4w       |                1     |    0.01 | 334600 | 2515.3       |   18.8028 | 0.75%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | android    | 4w       |                1     |    0.05 | 334592 | 2684.79      |   22.7306 | 0.85%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 4w       |                1     |    0.01 | 334592 | 2684.79      |   27.7205 | 1.03%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | android    | 4w       |                1     |    0.05 | 334592 | 2517.11      |   15.5559 | 0.62%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 4w       |                1     |    0.01 | 334592 | 2517.11      |   18.9708 | 0.75%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | android    | 4w       |                1     |    0.05 | 972131 |    0.180234  |    0.0015 | 0.86%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | android    | 4w       |                1     |    0.01 | 972131 |    0.180234  |    0.0019 | 1.04%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 2w       |                0.125 |    0.05 |   4220 |    0.0590785 |    0.0045 | 7.55%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 2w       |                0.125 |    0.01 |   4220 |    0.0590785 |    0.0054 | 9.21%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 2w       |                0.125 |    0.05 |   3749 | 1427.43      |  138.489  | 9.7%          | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 2w       |                0.125 |    0.01 |   3749 | 1427.43      |  168.948  | 11.84%        | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 2w       |                0.125 |    0.05 |   3916 | 2915.87      |  171.32   | 5.88%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 2w       |                0.125 |    0.01 |   3916 | 2915.87      |  209      | 7.17%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 2w       |                0.125 |    0.05 |   3954 | 3283.97      | 1250.94   | 38.09%        | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 2w       |                0.125 |    0.01 |   3954 | 3283.97      | 1526.08   | 46.47%        | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 2w       |                0.125 |    0.05 |   3996 | 2900.62      |  191.886  | 6.62%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 2w       |                0.125 |    0.01 |   3996 | 2900.62      |  234.096  | 8.07%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 2w       |                0.125 |    0.05 |  30707 |    0.0600515 |    0.0054 | 8.95%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 2w       |                0.125 |    0.01 |  30707 |    0.0600515 |    0.0066 | 10.91%        | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 2w       |                0.25  |    0.05 |   8550 |    0.0610328 |    0.0033 | 5.39%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 2w       |                0.25  |    0.01 |   8550 |    0.0610328 |    0.004  | 6.57%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 2w       |                0.25  |    0.05 |   7400 | 1473.22      |   97.6975 | 6.63%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 2w       |                0.25  |    0.01 |   7400 | 1473.22      |  119.179  | 8.09%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 2w       |                0.25  |    0.05 |   7963 | 2827.61      |  121.109  | 4.28%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 2w       |                0.25  |    0.01 |   7963 | 2827.61      |  147.736  | 5.22%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 2w       |                0.25  |    0.05 |   7952 | 3029.33      |  152.853  | 5.05%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 2w       |                0.25  |    0.01 |   7952 | 3029.33      |  186.458  | 6.16%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 2w       |                0.25  |    0.05 |   8041 | 2962.31      |  190.048  | 6.42%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 2w       |                0.25  |    0.01 |   8041 | 2962.31      |  231.832  | 7.83%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 2w       |                0.25  |    0.05 |  61376 |    0.0608218 |    0.0038 | 6.29%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 2w       |                0.25  |    0.01 |  61376 |    0.0608218 |    0.0047 | 7.67%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 2w       |                0.5   |    0.05 |  17012 |    0.059371  |    0.0023 | 3.82%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 2w       |                0.5   |    0.01 |  17012 |    0.059371  |    0.0028 | 4.67%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 2w       |                0.5   |    0.05 |  14920 | 1416.9       |   58.4864 | 4.13%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 2w       |                0.5   |    0.01 |  14920 | 1416.9       |   71.345  | 5.04%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 2w       |                0.5   |    0.05 |  15866 | 2868.5       |   90.726  | 3.16%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 2w       |                0.5   |    0.01 |  15866 | 2868.5       |  110.666  | 3.86%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 2w       |                0.5   |    0.05 |  16079 | 3059.85      |  115.665  | 3.78%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 2w       |                0.5   |    0.01 |  16079 | 3059.85      |  141.09   | 4.61%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 2w       |                0.5   |    0.05 |  15921 | 2872.03      |  107.85   | 3.76%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 2w       |                0.5   |    0.01 |  15921 | 2872.03      |  131.555  | 4.58%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 2w       |                0.5   |    0.05 | 122768 |    0.0606754 |    0.0027 | 4.45%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 2w       |                0.5   |    0.01 | 122768 |    0.0606754 |    0.0033 | 5.43%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 2w       |                0.75  |    0.05 |  25504 |    0.0600971 |    0.002  | 3.26%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 2w       |                0.75  |    0.01 |  25504 |    0.0600971 |    0.0024 | 3.98%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 2w       |                0.75  |    0.05 |  22282 | 1400.79      |   36.9998 | 2.64%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 2w       |                0.75  |    0.01 |  22282 | 1400.79      |   45.1348 | 3.22%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 2w       |                0.75  |    0.05 |  23802 | 2878.17      |   77.1707 | 2.68%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 2w       |                0.75  |    0.01 |  23802 | 2878.17      |   94.129  | 3.27%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 2w       |                0.75  |    0.05 |  23974 | 3115.53      |  225.529  | 7.24%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 2w       |                0.75  |    0.01 |  23974 | 3115.53      |  275.104  | 8.83%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 2w       |                0.75  |    0.05 |  23904 | 2874.19      |   83.38   | 2.9%          | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 2w       |                0.75  |    0.01 |  23904 | 2874.19      |  101.706  | 3.54%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 2w       |                0.75  |    0.05 | 184140 |    0.0597643 |    0.0022 | 3.66%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 2w       |                0.75  |    0.01 | 184140 |    0.0597643 |    0.0027 | 4.47%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 2w       |                1     |    0.05 |  34047 |    0.0605011 |    0.0017 | 2.81%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 2w       |                1     |    0.01 |  34047 |    0.0605011 |    0.0021 | 3.43%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 2w       |                1     |    0.05 |  29737 | 1414.39      |   39.583  | 2.8%          | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 2w       |                1     |    0.01 |  29737 | 1414.39      |   48.2877 | 3.41%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 2w       |                1     |    0.05 |  31814 | 2873.52      |   66.3287 | 2.31%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 2w       |                1     |    0.01 |  31814 | 2873.52      |   80.9164 | 2.82%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 2w       |                1     |    0.05 |  31826 | 3090.03      |  173.084  | 5.6%          | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 2w       |                1     |    0.01 |  31826 | 3090.03      |  211.15   | 6.83%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 2w       |                1     |    0.05 |  31826 | 2886.24      |   70.0084 | 2.43%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 2w       |                1     |    0.01 |  31826 | 2886.24      |   85.4053 | 2.96%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 2w       |                1     |    0.05 | 245537 |    0.0604512 |    0.0019 | 3.15%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 2w       |                1     |    0.01 | 245537 |    0.0604512 |    0.0023 | 3.85%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 3w       |                0.125 |    0.05 |   5668 |    0.0586396 |    0.0038 | 6.56%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# ...
# | web        | 3w       |                0.75  |    0.01 |  30058 | 1433.54      |   59.1721 | 4.13%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 3w       |                0.75  |    0.05 |  31974 | 2843.24      |   61.9711 | 2.18%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 3w       |                0.75  |    0.01 |  31974 | 2843.24      |   75.5997 | 2.66%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 3w       |                0.75  |    0.05 |  31964 | 3063.91      |   84.1121 | 2.75%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 3w       |                0.75  |    0.01 |  31964 | 3063.91      |  102.61   | 3.35%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 3w       |                0.75  |    0.05 |  32046 | 2884.45      |   68.2816 | 2.37%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 3w       |                0.75  |    0.01 |  32046 | 2884.45      |   83.2976 | 2.89%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 3w       |                0.75  |    0.05 | 245194 |    0.0635456 |    0.002  | 3.07%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 3w       |                0.75  |    0.01 | 245194 |    0.0635456 |    0.0024 | 3.75%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 3w       |                1     |    0.05 |  45686 |    0.0594275 |    0.0015 | 2.51%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 3w       |                1     |    0.01 |  45686 |    0.0594275 |    0.0018 | 3.06%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 3w       |                1     |    0.05 |  40003 | 1442.14      |   39.9789 | 2.77%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 3w       |                1     |    0.01 |  40003 | 1442.14      |   48.7616 | 3.38%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 3w       |                1     |    0.05 |  42702 | 2854.9       |   57.7725 | 2.02%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 3w       |                1     |    0.01 |  42702 | 2854.9       |   70.4823 | 2.47%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 3w       |                1     |    0.05 |  42718 | 3117.9       |  172.561  | 5.53%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 3w       |                1     |    0.01 |  42718 | 3117.9       |  210.524  | 6.75%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 3w       |                1     |    0.05 |  42718 | 2852.41      |   55.3826 | 1.94%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 3w       |                1     |    0.01 |  42718 | 2852.41      |   67.5666 | 2.37%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 3w       |                1     |    0.05 | 326958 |    0.0634026 |    0.0017 | 2.66%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 3w       |                1     |    0.01 | 326958 |    0.0634026 |    0.0021 | 3.25%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 4w       |                0.125 |    0.05 |   7139 |    0.0592061 |    0.0033 | 5.64%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 4w       |                0.125 |    0.01 |   7139 |    0.0592061 |    0.0041 | 6.88%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 4w       |                0.125 |    0.05 |   6304 | 1485.17      |  108.027  | 7.27%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 4w       |                0.125 |    0.01 |   6304 | 1485.17      |  131.782  | 8.87%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 4w       |                0.125 |    0.05 |   6782 | 2861.45      |  146.846  | 5.13%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 4w       |                0.125 |    0.01 |   6782 | 2861.45      |  179.141  | 6.26%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 4w       |                0.125 |    0.05 |   6751 | 2971.37      |  156.903  | 5.28%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 4w       |                0.125 |    0.01 |   6751 | 2971.37      |  191.41   | 6.44%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 4w       |                0.125 |    0.05 |   6738 | 2845.92      |  139.85   | 4.91%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 4w       |                0.125 |    0.01 |   6738 | 2845.92      |  170.606  | 5.99%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 4w       |                0.125 |    0.05 |  50217 |    0.0682239 |    0.0045 | 6.53%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 4w       |                0.125 |    0.01 |  50217 |    0.0682239 |    0.0054 | 7.97%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 4w       |                0.25  |    0.05 |  14250 |    0.0604585 |    0.0029 | 4.73%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 4w       |                0.25  |    0.01 |  14250 |    0.0604585 |    0.0035 | 5.77%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 4w       |                0.25  |    0.05 |  12501 | 1455.92      |   67.434  | 4.63%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 4w       |                0.25  |    0.01 |  12501 | 1455.92      |   82.2616 | 5.65%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 4w       |                0.25  |    0.05 |  13418 | 2838.02      |   90.5439 | 3.19%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 4w       |                0.25  |    0.01 |  13418 | 2838.02      |  110.446  | 3.89%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 4w       |                0.25  |    0.05 |  13358 | 3157.28      |  358.002  | 11.34%        | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 4w       |                0.25  |    0.01 |  13358 | 3157.28      |  436.743  | 13.83%        | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 4w       |                0.25  |    0.05 |  13370 | 2853.74      |   93.6256 | 3.28%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 4w       |                0.25  |    0.01 |  13370 | 2853.74      |  114.218  | 4.0%          | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 4w       |                0.25  |    0.05 | 100410 |    0.0660094 |    0.0031 | 4.7%          | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 4w       |                0.25  |    0.01 | 100410 |    0.0660094 |    0.0038 | 5.74%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 4w       |                0.5   |    0.05 |  28626 |    0.0594936 |    0.0018 | 2.97%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 4w       |                0.5   |    0.01 |  28626 |    0.0594936 |    0.0022 | 3.63%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 4w       |                0.5   |    0.05 |  25154 | 1454.59      |   54.3648 | 3.74%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 4w       |                0.5   |    0.01 |  25154 | 1454.59      |   66.3164 | 4.56%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 4w       |                0.5   |    0.05 |  26732 | 2851.24      |   69.541  | 2.44%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 4w       |                0.5   |    0.01 |  26732 | 2851.24      |   84.8315 | 2.98%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 4w       |                0.5   |    0.05 |  26896 | 3180.18      |  357.288  | 11.23%        | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 4w       |                0.5   |    0.01 |  26896 | 3180.18      |  435.848  | 13.71%        | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 4w       |                0.5   |    0.05 |  26713 | 2861.67      |   67.1007 | 2.34%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 4w       |                0.5   |    0.01 |  26713 | 2861.67      |   81.8547 | 2.86%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 4w       |                0.5   |    0.05 | 200818 |    0.0677081 |    0.0022 | 3.28%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 4w       |                0.5   |    0.01 | 200818 |    0.0677081 |    0.0027 | 4.0%          | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 4w       |                0.75  |    0.05 |  42892 |    0.0603117 |    0.0016 | 2.67%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 4w       |                0.75  |    0.01 |  42892 |    0.0603117 |    0.002  | 3.26%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 4w       |                0.75  |    0.05 |  37515 | 1458.59      |   45.9271 | 3.15%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 4w       |                0.75  |    0.01 |  37515 | 1458.59      |   56.0228 | 3.84%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 4w       |                0.75  |    0.05 |  40162 | 2855.11      |   57.8889 | 2.03%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 4w       |                0.75  |    0.01 |  40162 | 2855.11      |   70.6044 | 2.47%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 4w       |                0.75  |    0.05 |  40086 | 3079.76      |  135.111  | 4.39%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 4w       |                0.75  |    0.01 |  40086 | 3079.76      |  164.79   | 5.35%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 4w       |                0.75  |    0.05 |  40272 | 2865.04      |   56.8605 | 1.98%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 4w       |                0.75  |    0.01 |  40272 | 2865.04      |   69.349  | 2.42%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 4w       |                0.75  |    0.05 | 301248 |    0.0671706 |    0.0018 | 2.69%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 4w       |                0.75  |    0.01 | 301248 |    0.0671706 |    0.0022 | 3.28%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 4w       |                1     |    0.05 |  57238 |    0.0592291 |    0.0014 | 2.32%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 4w       |                1     |    0.01 |  57238 |    0.0592291 |    0.0017 | 2.83%         | ('not_found', 'total_items')                    | Доля отмен/замен                  |
# | web        | 4w       |                1     |    0.05 |  50136 | 1459.25      |   41.0555 | 2.81%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 4w       |                1     |    0.01 |  50136 | 1459.25      |   50.0819 | 3.43%         | ('assembly_speed_positions_num', 'n_shipments') | Среднее время сборки              |
# | web        | 4w       |                1     |    0.05 |  53559 | 2867.44      |   48.693  | 1.7%          | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 4w       |                1     |    0.01 |  53559 | 2867.44      |   59.4018 | 2.07%         | ('goods', 'order_number_x')                     | Средний чек                       |
# | web        | 4w       |                1     |    0.05 |  53576 | 3066.39      |   66.9832 | 2.18%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 4w       |                1     |    0.01 |  53576 | 3066.39      |   81.7145 | 2.66%         | ('aov_initial_before', 'order_number_y')        | Средний чек по line_items (до)    |
# | web        | 4w       |                1     |    0.05 |  53576 | 2852.77      |   48.3469 | 1.69%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 4w       |                1     |    0.01 |  53576 | 2852.77      |   58.9796 | 2.07%         | ('aov_initial_after', 'order_number_y')         | Средний чек по line_items (после) |
# | web        | 4w       |                1     |    0.05 | 401648 |    0.067233  |    0.0016 | 2.33%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |
# | web        | 4w       |                1     |    0.01 | 401648 |    0.067233  |    0.0019 | 2.84%         | ('ret_14d_within_retilist', None)               | Ретеншн 14д                       |

# %% [markdown]
# # AA & AB

# %%
synthetic_data = {}
for l in tqdm(lengths):
    name = f"{l}w"
    tmp = get_not_found_ratio_oos(platforms, end_date - dt.timedelta(weeks = l), end_date,  sources_web, sources_new_app)
    synthetic_data[name] = tmp
# Out:
# 100%|██████████| 3/3 [42:51<00:00, 857.01s/it]

# %%
alpha = 0.05
sample_size = 0.5
effect = -0.1

# %%
traffic_proportions = [1]

# %% [markdown]
# ## AA

# %%
# %%time
out = {"platform": [], 
       "length": [], 
       "traffic_proportion": [], 
       "power":[]
}
p_values = {}

for platform in platforms:
    for length in data.keys():
        for traffic_proportion in traffic_proportions:
            
            state = f'{platform}_{length}_{traffic_proportion}'
            
            df_users = synthetic_data[length][['anonymous_id']].drop_duplicates().sample(frac=traffic_proportion)
            df_raw = synthetic_data[length].query('platform == @platform').query('anonymous_id.isin(@df_users.anonymous_id.tolist())', engine='python')
                        
            df_raw['weekday'] = df_raw.completed_at.dt.weekday + 1 
            
            p_values[state] = []
            
            for _ in tqdm(range(100)):
                
                df = df_raw.sort_values(by = 'not_found', ascending = False).copy()
                
                test_users = df_users.sample(frac=0.5)
                df['group'] = np.where(df.anonymous_id.isin(test_users.anonymous_id.values),'test','control')
                
                df_metrics = df.groupby(["anonymous_id", "platform","group"])[['not_found','total_items']].sum().reset_index()
                
                p, _, _ = calculate_pvalue('test', 'control', ('not_found','total_items'), 'group', df_metrics, metric_type='ratio')
                p_values[state].append(p)
                

            errors = (np.array(p_values[state])>alpha).astype(int)
            power = 1 - np.mean(errors)
                
            out['platform'].append(platform)
            out['length'].append(length)
            out['traffic_proportion'].append(traffic_proportion)
            out['power'].append(power)
# Out:
# 100%|██████████| 100/100 [04:51<00:00,  2.92s/it]
# 100%|██████████| 100/100 [06:59<00:00,  4.19s/it]
# 100%|██████████| 100/100 [09:12<00:00,  5.53s/it]
# 100%|██████████| 100/100 [00:46<00:00,  2.15it/s]
# 100%|██████████| 100/100 [01:11<00:00,  1.40it/s]
# 100%|██████████| 100/100 [01:25<00:00,  1.16it/s]
# CPU times: user 24min 16s, sys: 21.1 s, total: 24min 37s
# Wall time: 24min 38s

# %%
pd.DataFrame(out)
# Out:
#   platform length  traffic_proportion  power
# 0  android     2w                   1   0.05
# 1  android     3w                   1   0.04
# 2  android     4w                   1   0.05
# 3      web     2w                   1   0.03
# 4      web     3w                   1   0.07
# 5      web     4w                   1   0.03

# %%
np.sum(np.array(p_values['web_2w_1'])>0.05)
# Out:
# 100

# %%
p_values['web_2w_1']
# Out:
# [0.36898239203911387,
#  0.33937531707227586,
#  0.30875933255099847,
#  0.3440126553493108,
#  0.292256820155299,
#  0.33359924888017645,
#  0.29562825438984636,
#  0.34977656211211117,
#  0.25518476354985037,
#  0.3237396451878439,
#  0.39342655685748085,
#  0.32017998346441584,
#  0.2682432301481323,
#  0.36069049711422185,
#  0.32883655137085277,
#  0.3192357159804766,
#  0.38004870182756023,
#  0.35693704152081196,
#  0.3800836526263771,
#  0.34644846131669427,
#  0.31301718612660206,
#  0.32730386931465283,
#  0.31585108833239695,
#  0.3166405157374499,
#  0.32444230714531586,
#  0.2503063411936794,
#  0.27207257464251416,
#  0.33971896257504897,
#  0.30725518833695237,
#  0.4242375740709726,
#  0.24887214453063766,
#  0.3560841384714546,
#  0.32241109542533875,
#  0.3748666502510756,
#  0.35450875238633606,
#  0.2981656677553302,
#  0.4055451862830265,
#  0.3493535833802641,
#  0.35601983561516515,
#  0.2940545515982298,
#  0.37829408041660106,
#  0.3489306692751132,
#  0.3044311384870983,
#  0.3365760650037406,
#  0.32434286959825254,
#  0.322242105660448,
#  0.3055374850977459,
#  0.3270381166720707,
#  0.3515393841119525,
#  0.3211256951322766,
#  0.36108418096158534,
#  0.36792419575350455,
#  0.28628272225496026,
#  0.30815056602351104,
#  0.3045029840888724,
#  0.25986228642995596,
#  0.2959546663391378,
#  0.30769765718671915,
#  0.31474607939764343,
#  0.3398371023914394,
#  0.3251283479018502,
#  0.33242893486568637,
#  0.3211657020787606,
#  0.33754757375399225,
#  0.3567843167890077,
#  0.3400034642151132,
#  0.3137973579519544,
#  0.31571467519913665,
#  0.32005114335145923,
#  0.2958494465798381,
#  0.329264244722292,
#  0.3660333275783839,
#  0.23494709925360724,
#  0.35202344802213836,
#  0.30348917184345403,
#  0.353764965301547,
#  0.30708526972033473,
#  0.3034050993724365,
#  0.4089647726029838,
#  0.38802082477607225,
#  0.35234350862207175,
#  0.30250361854415403,
#  0.35285149001874894,
#  0.3303439088289224,
#  0.33742735434031956,
#  0.3398189055626516,
#  0.29033544507018216,
#  0.43746593077223306,
#  0.2977349911818144,
#  0.29005911268519774,
#  0.27819891984709394,
#  0.3049956177218699,
#  0.2524840880544775,
#  0.31883241648503713,
#  0.3069447802141081,
#  0.2992211575754591,
#  0.3645998155658482,
#  0.2879497633351672,
#  0.3218481847155232,
#  0.2636150982024861]

# %% [markdown]
# ### AB

# %%
effect = -0.05

# %%
# %%time
out = {"platform": [], 
       "length": [], 
       "traffic_proportion": [], 
       "power":[]
}
p_values = {}

for platform in platforms:
    for length in data.keys():
        for traffic_proportion in traffic_proportions:
            
            state = f'{platform}_{length}_{traffic_proportion}'
            
            df_users = synthetic_data[length][['anonymous_id']].drop_duplicates().sample(frac=traffic_proportion)
            df_raw = synthetic_data[length].query('platform == @platform').query('anonymous_id.isin(@df_users.anonymous_id.tolist())', engine='python')
                        
            df_raw['weekday'] = df_raw.completed_at.dt.weekday + 1
            
            p_values[state] = []
            
            for _ in tqdm(range(100)):
                
                df = df_raw.sort_values(by = 'not_found', ascending = False).copy()
                
                test_users = df_users.sample(frac=0.5)
                df['group'] = np.where(df.anonymous_id.isin(test_users.anonymous_id.values),'test','control')
                tmp = (
                    df
                    .query('group=="test"')
                    .query("weekday.isin([5,6,7,1])", engine='python')
                    [['anonymous_id','platform','order_number','not_found']]
                )
                
                old_not_found_total = tmp.not_found.sum()
                new_not_found_total = int(old_not_found_total*(1+effect))
                tmp['weight'] = tmp.not_found / tmp.not_found.sum()
                tmp['new_not_found'] = np.round(tmp.weight*new_not_found_total)
                tmp['kostyl'] = tmp.new_not_found.cumsum()
                tmp.loc[tmp.kostyl>new_not_found_total, 'new_not_found'] = 0
                
                df = df.merge(tmp[['anonymous_id','platform','order_number','new_not_found']], on = ['anonymous_id','platform','order_number'], how = 'left')
                df['final_not_found'] = df.not_found
                df.loc[df['new_not_found'].notna(), 'final_not_found'] = df['new_not_found']
                
                df_metrics = df.groupby(["anonymous_id", "platform","group"])[['final_not_found','total_items']].sum().reset_index()
                
                p, _, _ = calculate_pvalue('test', 'control', ('final_not_found','total_items'), 'group', df_metrics, metric_type='ratio')
                p_values[state].append(p)
                

            errors = (np.array(p_values[state])>alpha).astype(int)
            power = 1 - np.mean(errors)
                
            out['platform'].append(platform)
            out['length'].append(length)
            out['traffic_proportion'].append(traffic_proportion)
            out['power'].append(power)
# Out:
# 100%|██████████| 100/100 [08:19<00:00,  4.99s/it]
# 100%|██████████| 100/100 [12:02<00:00,  7.23s/it]
# 100%|██████████| 100/100 [16:12<00:00,  9.73s/it]
# 100%|██████████| 100/100 [01:05<00:00,  1.52it/s]
# 100%|██████████| 100/100 [01:41<00:00,  1.01s/it]
# 100%|██████████| 100/100 [02:07<00:00,  1.28s/it]
# CPU times: user 40min 7s, sys: 1min 30s, total: 41min 38s
# Wall time: 41min 40s

# %%
pd.DataFrame(out)
# Out:
#   platform length  traffic_proportion  power
# 0  android     2w                   1   1.00
# 1  android     3w                   1   1.00
# 2  android     4w                   1   1.00
# 3      web     2w                   1   0.90
# 4      web     3w                   1   0.98
# 5      web     4w                   1   0.98

# %%
p_values
# Out:
# {'android_2w_1': [2.5709574176189915e-77,
#   7.135668096207158e-81,
#   4.250476604311184e-89,
#   7.098531939336588e-79,
#   1.241327868542202e-85,
#   9.704407793047085e-78,
#   2.899874046530344e-54,
#   2.0921322263528e-90,
#   2.7389492462767956e-72,
#   1.2950266322627779e-87,
#   1.0598767550622386e-69,
#   1.358287213235657e-78,
#   9.460556727161592e-88,
#   8.164073913702496e-84,
#   1.1416273828025342e-91,
#   1.214196954025985e-78,
#   7.003667817585489e-80,
#   5.932734639017576e-72,
#   2.8718014003322634e-77,
#   5.383682761868047e-91,
#   6.868125668483939e-82,
#   2.03071131991529e-79,
#   4.535219624266471e-65,
#   9.337395859510062e-80,
#   3.625803746066295e-82,
#   4.177026193193421e-95,
#   1.312533609963917e-88,
#   2.495624368831387e-84,
#   2.6046626376416986e-89,
#   6.305025443387996e-88,
#   1.859488857186489e-71,
#   9.795228519333371e-73,
#   1.9127785081040375e-86,
#   3.092480139300434e-88,
#   4.206572834151088e-76,
#   1.1385043040492983e-85,
#   1.0840210737311506e-84,
#   1.142336348887695e-91,
#   1.3823729030789968e-84,
#   3.12200531669554e-74,
#   1.842986886673869e-83,
#   2.72132007841308e-73,
#   3.301803757949724e-75,
#   6.327359983247177e-74,
#   1.5959068494906861e-77,
#   8.855180218424054e-79,
#   1.1094236682347646e-76,
#   1.694571792688048e-83,
#   2.0988059574951784e-77,
#   8.296309841338852e-82,
#   3.6082216453788373e-85,
#   1.760237068681805e-77,
#   1.0466308628587562e-85,
#   3.669032015825137e-89,
#   1.4168079970288918e-94,
#   3.565267238127192e-74,
#   1.7180419487996195e-80,
#   3.3473786202548294e-84,
#   8.681043317550641e-88,
#   5.668203556177754e-100,
#   6.066492579791752e-76,
#   9.413809109458827e-93,
#   2.743889303258842e-96,
#   1.0837613699549418e-78,
#   6.04655929874477e-71,
#   3.0516571023968706e-85,
#   5.081993268664854e-72,
#   3.519831639993459e-73,
#   1.2595384073850994e-87,
#   1.553196786603506e-58,
#   3.809531442541556e-89,
#   7.922539198580159e-89,
#   6.225288669436121e-91,
#   3.1413987824855767e-78,
#   4.086300109545246e-77,
#   7.651936075322911e-99,
#   2.7434627260641073e-87,
#   2.4625399917684327e-79,
#   9.916409600968545e-76,
#   8.369581726144821e-75,
#   8.459180263748434e-77,
#   2.4326908191356796e-93,
#   8.40621020636919e-71,
#   2.335945125628346e-88,
#   7.784890116687562e-70,
#   7.315196670169269e-78,
#   1.0240152464803496e-91,
#   5.362819296700759e-78,
#   6.876294263744949e-87,
#   1.1818643128159827e-93,
#   4.0697283038928916e-66,
#   6.828645670050671e-82,
#   1.0327081779486782e-93,
#   4.387631473739165e-80,
#   3.1971249330661318e-83,
#   1.479593878659439e-84,
#   3.0216539999868343e-76,
#   7.393023443887925e-98,
#   2.648809017050181e-69,
#   3.507428434998923e-84],
#  'android_3w_1': [4.706283901352672e-101,
#   4.546615884280806e-98,
#   1.8849949484061255e-119,
#   8.966213943442032e-108,
#   7.3124875471343864e-99,
#   5.639791219363369e-92,
#   2.8535176266955522e-112,
#   2.423229806999064e-105,
#   1.2954254549793807e-105,
#   4.4298165409825667e-116,
#   1.0719116159186533e-108,
#   1.9570295836323404e-119,
#   5.686318343117683e-103,
#   5.965487704556628e-128,
#   6.357194539914535e-100,
#   1.9533800098788957e-98,
#   9.274480596392018e-111,
#   1.012130541177822e-100,
#   1.5125162827238242e-108,
#   7.47705813880179e-109,
#   3.426815490355716e-121,
#   2.934471337487036e-94,
#   2.9328564713434217e-107,
#   5.443768042768684e-108,
#   6.107973209550954e-110,
#   1.6686694969763371e-90,
#   1.613514760774188e-102,
#   5.144093814818052e-106,
#   2.425318565800121e-95,
#   2.847955218800353e-105,
#   1.6186834093677239e-105,
#   9.22602459375387e-114,
#   9.937554279906538e-116,
#   1.4192814843995777e-115,
#   3.470101026368874e-115,
#   1.737568509660976e-109,
#   1.0816377715435806e-84,
#   3.6027508593531995e-91,
#   1.7974492393659383e-107,
#   1.4890427942689574e-113,
#   3.4732143330513325e-119,
#   1.1491154053131131e-115,
#   2.6089753886477014e-99,
#   7.3191384547764594e-121,
#   8.142052605750434e-109,
#   3.691232257702071e-108,
#   3.9125845396853354e-113,
#   1.2956207100840606e-111,
#   1.992137866525727e-101,
#   7.428453333395264e-116,
#   6.371712419150204e-97,
#   1.2466451312780906e-94,
#   4.6227760138569633e-104,
#   5.133037702058033e-116,
#   3.7051416537821694e-106,
#   2.7874276507186597e-102,
#   1.7032137196558717e-104,
#   2.343392352646328e-119,
#   4.263521491351373e-101,
#   5.750453344924178e-123,
#   2.418658952296979e-111,
#   1.946315369131037e-116,
#   6.720490777655207e-123,
#   4.68954047777478e-108,
#   1.1352140211554968e-105,
#   1.7386736214197723e-120,
#   1.508620364567994e-81,
#   2.0893347884816185e-109,
#   6.504059373986378e-97,
#   4.374906789425618e-85,
#   3.0374392322172268e-90,
#   5.140349973555559e-111,
#   1.5231080385168602e-118,
#   9.318240194822392e-113,
#   1.6434735784882233e-111,
#   1.3914600959379452e-107,
#   1.0936220999259248e-103,
#   2.3496891236845605e-102,
#   1.3599357291915253e-97,
#   3.4236639234909434e-122,
#   3.4649490580803796e-122,
#   7.508116850433489e-100,
#   9.063803559067406e-108,
#   2.830182795176906e-105,
#   4.6045968706319933e-104,
#   2.5903670264359676e-102,
#   9.429969423627072e-123,
#   7.893885408174617e-110,
#   9.030370364964062e-109,
#   5.500360786479061e-112,
#   1.234809588716516e-115,
#   2.0467087423052833e-111,
#   1.5959676580643735e-108,
#   1.4258460942955504e-103,
#   5.56579796717997e-96,
#   5.380349050502561e-103,
#   7.170909922331832e-129,
#   1.4847721230878653e-115,
#   5.141248547790536e-109,
#   1.82163454118417e-110],
#  'android_4w_1': [2.709965694661627e-134,
#   7.104156406336363e-158,
#   6.948090450386803e-138,
#   2.0071630522454923e-126,
#   5.688306735094165e-135,
#   5.978456844587332e-145,
#   1.117322528823116e-144,
#   3.857640863766057e-132,
#   6.60368790071031e-126,
#   4.995619494464083e-137,
#   4.7917903270321587e-141,
#   1.01465057811518e-124,
#   3.718418427393709e-127,
#   8.974978613091322e-134,
#   8.363954897936772e-126,
#   7.343735395235809e-160,
#   5.0167619907866187e-129,
#   5.11244606790576e-152,
#   1.7224542343785073e-158,
#   1.1164184415458004e-127,
#   4.9090030109825655e-148,
#   7.132268168670968e-138,
#   2.1507391645671528e-148,
#   1.1665337172710083e-127,
#   6.434854235736413e-143,
#   1.3968498044102459e-121,
#   6.162915977466135e-136,
#   3.23183728197386e-143,
#   2.720662461111853e-133,
#   1.3854106147137939e-145,
#   4.0700328831837733e-137,
#   2.487310413307876e-145,
#   5.643730876928166e-133,
#   3.3168150076128232e-127,
#   3.859847977472732e-125,
#   2.10460485656209e-127,
#   3.249831792061644e-127,
#   1.130663046176523e-136,
#   7.214040178803928e-139,
#   1.378421040678427e-126,
#   1.0317235676236312e-134,
#   3.330412325672688e-128,
#   4.219609671578663e-127,
#   3.208970339066097e-147,
#   8.184196675332664e-129,
#   4.879239509086386e-128,
#   6.394690798979876e-132,
#   6.921900622960249e-121,
#   2.3310012033387083e-117,
#   2.014905814173272e-130,
#   3.6091123057017225e-133,
#   4.3735586471788976e-139,
#   3.0217673494670746e-134,
#   3.5903068951428216e-145,
#   5.564182678726923e-127,
#   6.21884969773808e-141,
#   2.633627740127984e-122,
#   2.169293751609765e-131,
#   1.6407612407495556e-142,
#   1.387789364413282e-126,
#   2.8566401133255364e-124,
#   9.772537887266479e-126,
#   4.099079789453796e-122,
#   3.2315127855529514e-127,
#   6.448187769033019e-120,
#   5.835651771668788e-124,
#   2.8645606405613043e-127,
#   4.5097977592320037e-116,
#   7.415432449894542e-120,
#   7.750559991677761e-125,
#   1.6803447320488468e-129,
#   7.986410846138969e-136,
#   1.5021212576405546e-141,
#   4.205379081997375e-141,
#   4.932019553604512e-137,
#   4.130954524780225e-119,
#   5.859665132376682e-112,
#   1.3803299778283413e-115,
#   1.4756785846217764e-132,
#   1.500856448293687e-128,
#   1.0802067125986678e-120,
#   1.6290060493241189e-133,
#   9.814162382084078e-123,
#   3.3080099446195325e-130,
#   8.624801260156976e-156,
#   2.1339345313658424e-141,
#   3.7936861923368194e-121,
#   4.304843895300876e-117,
#   3.7721879848902287e-135,
#   1.5075245684284275e-117,
#   7.37919548042255e-132,
#   3.720742293928466e-129,
#   6.178620628616415e-120,
#   2.8193250889658824e-135,
#   5.420716298641935e-119,
#   2.599634556242242e-137,
#   2.066444347621732e-144,
#   5.807263230838872e-135,
#   4.446584426313603e-126,
#   7.729406195897556e-129],
#  'web_2w_1': [1.8801404322616223e-12,
#   1.3256218531125883e-10,
#   6.19696575499732e-11,
#   2.1164905433331455e-11,
#   3.4866511458441975e-12,
#   7.417205678167717e-13,
#   5.595267507021484e-14,
#   1.015645244772662e-08,
#   3.129045657056337e-06,
#   1.320170193198168e-07,
#   2.170741093433476e-12,
#   1.410605051772294e-08,
#   3.2740952188885384e-12,
#   3.55274905909879e-16,
#   9.574985954556408e-12,
#   1.9238466817925763e-10,
#   1.8139293965342712e-13,
#   2.1590660702964628e-11,
#   5.387987782420444e-07,
#   1.272624643094536e-12,
#   2.3774231196472557e-05,
#   7.533174395139202e-15,
#   9.196900001212306e-06,
#   2.508844442387962e-15,
#   6.162587205772447e-13,
#   2.0851273080303694e-10,
#   1.415777386814114e-11,
#   3.2948612780825183e-09,
#   4.931323935527292e-12,
#   2.170717312708113e-15,
#   2.987744741659607e-08,
#   2.540071182873072e-14,
#   5.205562965761465e-12,
#   3.6187010095844655e-09,
#   1.3028253104114777e-08,
#   4.4720088325167323e-11,
#   1.269560518713357e-10,
#   5.342393820355753e-20,
#   7.407209303826235e-15,
#   2.026248406736176e-09,
#   3.438990404596076e-06,
#   1.696973855735405e-07,
#   3.284876790302224e-10,
#   3.0048305142555367e-12,
#   1.2410848506204381e-07,
#   1.427532803070333e-10,
#   1.0695352229721168e-11,
#   3.441849437960245e-08,
#   1.8818863555281815e-14,
#   3.277914881596978e-10,
#   4.245071088079547e-08,
#   2.250233242020868e-06,
#   1.0102326128591961e-13,
#   2.3015126738086742e-15,
#   2.3310886506944127e-14,
#   5.122060231196576e-13,
#   1.316342205255127e-07,
#   2.7553111056601768e-15,
#   2.706310712411762e-10,
#   9.269100836100408e-14,
#   8.649099231090471e-13,
#   6.624007217872232e-13,
#   7.482769134798775e-12,
#   1.1754546695805684e-13,
#   5.411938439970262e-11,
#   2.2597925125788497e-10,
#   2.2835932280975325e-15,
#   1.3885502412984328e-09,
#   2.852287157688125e-10,
#   9.422234164616433e-10,
#   4.832861086771769e-14,
#   1.8411187997118802e-13,
#   5.268590651827879e-19,
#   3.549455024381078e-12,
#   1.3216201739082858e-10,
#   4.731015296000518e-08,
#   1.1628834838981197e-08,
#   8.742164525491498e-10,
#   4.893765031720916e-07,
#   2.1014144049591333e-09,
#   4.736451284457359e-12,
#   8.094930757088367e-12,
#   8.835362111634635e-12,
#   2.7858069690741583e-16,
#   7.101760675913011e-14,
#   3.6648201468101397e-10,
#   4.479746904059474e-10,
#   2.1682010352750155e-08,
#   2.3053854544434296e-09,
#   1.0119524553993288e-08,
#   1.973050777903465e-14,
#   1.1893351073977563e-08,
#   5.699641082409638e-12,
#   8.994282900748299e-11,
#   5.278809843469411e-09,
#   9.794002496720187e-08,
#   1.9378584982560152e-12,
#   2.5177530850585035e-11,
#   1.4390009485023138e-11,
#   2.46219766766243e-17],
#  'web_3w_1': [1.7514395058914651e-10,
#   2.3091053981852594e-16,
#   3.2875959524709065e-10,
#   4.327061340388716e-14,
#   9.620334426917415e-15,
#   3.3051112314444504e-14,
#   5.940885303051079e-13,
#   8.68411262670273e-15,
#   1.6915917419773072e-19,
#   4.656685885996963e-12,
#   4.4282369304206174e-17,
#   7.394351871215195e-17,
#   1.544075675578367e-15,
#   2.1834542811011358e-10,
#   3.39599333614478e-11,
#   1.8941376741966496e-21,
#   2.4297799732858178e-21,
#   2.8695367041601446e-13,
#   3.889907910973121e-16,
#   7.684689266002866e-13,
#   1.6416253208207578e-15,
#   4.962150328339842e-16,
#   1.945191295405624e-09,
#   6.077232853924897e-15,
#   4.863362841655371e-11,
#   3.6168417508995694e-16,
#   5.0199645300866347e-14,
#   1.596890028420042e-14,
#   1.300916624873144e-16,
#   7.127793636173285e-13,
#   4.709265631070272e-12,
#   1.0937949367742141e-10,
#   5.244849973880136e-13,
#   4.842030270602412e-16,
#   2.1154439910302806e-18,
#   4.1340285516334545e-14,
#   4.53149611385235e-18,
#   2.512431904631146e-12,
#   4.958691720726108e-13,
#   1.3449560250295574e-11,
#   1.3892196390945916e-12,
#   2.97107079123397e-16,
#   2.9783164742525347e-15,
#   9.169769299763156e-15,
#   4.5956298235556234e-11,
#   1.5878166110194025e-08,
#   3.410780241568723e-16,
#   1.2925133765147992e-16,
#   1.3233496331190967e-10,
#   2.9665481619110203e-10,
#   2.447557374311007e-18,
#   4.7908831693058944e-17,
#   7.649056763234005e-13,
#   1.0112215815656417e-13,
#   3.1472437858750943e-13,
#   3.0185580510695533e-14,
#   4.746271312472172e-16,
#   3.430367161528906e-19,
#   1.1168306246116118e-10,
#   9.892375932790967e-12,
#   4.641386763370182e-14,
#   1.1861178305062666e-18,
#   4.687592010810046e-16,
#   2.785004851063407e-15,
#   2.4768007000202477e-08,
#   1.4519479106771203e-14,
#   4.399210572616503e-11,
#   4.52582429280006e-13,
#   7.518662605400575e-16,
#   1.4382261576573572e-12,
#   2.342701062111497e-15,
#   7.588477678081757e-14,
#   1.1704148390616564e-11,
#   1.6154759092695677e-09,
#   1.3553855961540254e-12,
#   9.45364772954067e-13,
#   6.6396945606450685e-15,
#   3.13598575447545e-10,
#   3.116075614942129e-09,
#   2.05371607042196e-06,
#   4.292096542923813e-17,
#   8.232935209310269e-13,
#   3.402940098098271e-13,
#   3.841127754457274e-19,
#   5.746989114984408e-17,
#   3.774033394501698e-09,
#   9.953442338852684e-19,
#   1.7887511527890528e-15,
#   1.5179899908271877e-12,
#   1.1766131547168684e-15,
#   1.8094828840137908e-10,
#   1.1761295213206591e-18,
#   1.0474557704729447e-13,
#   1.2480957469494075e-15,
#   7.509622437043821e-16,
#   9.920296620505586e-11,
#   2.7214839346585737e-16,
#   2.9461325078132283e-21,
#   2.883033479482991e-13,
#   3.498496842798796e-16],
#  'web_4w_1': [2.5516842427654734e-12,
#   2.1894396689361806e-14,
#   1.7890410578395638e-17,
#   3.387550177027293e-18,
#   2.2079732802559488e-17,
#   3.7373257352593285e-18,
#   1.320162999389046e-21,
#   5.881128139884148e-17,
#   5.148844453979711e-16,
#   8.221576055519088e-17,
#   2.9997716539429386e-18,
#   3.208214422442238e-13,
#   5.9690745240455244e-24,
#   4.50055558351805e-16,
#   1.1457860622859994e-14,
#   4.3860010986971246e-17,
#   3.25424485553977e-15,
#   7.3153572241135235e-19,
#   2.1010497462271247e-16,
#   7.438760613592364e-23,
#   9.645482752180683e-16,
#   2.0503528260774972e-26,
#   1.923819431508159e-20,
#   1.4756042702008123e-16,
#   2.4783803934805553e-16,
#   4.942980996216703e-14,
#   5.698726041434047e-26,
#   4.6159621018190993e-17,
#   8.127244446367935e-11,
#   6.114430315270098e-19,
#   4.5499153869572816e-23,
#   2.78423940489756e-17,
#   1.7058755651941152e-17,
#   1.3224609649814762e-12,
#   3.932308759570063e-25,
#   2.1714543586877968e-15,
#   3.3786069101176884e-20,
#   5.739504977428035e-20,
#   1.431978295469087e-21,
#   1.318553020740654e-15,
#   2.983142800366206e-19,
#   4.85345928555754e-25,
#   1.7169358019444016e-17,
#   1.8706944564904308e-17,
#   1.1140595456747032e-10,
#   3.443742396964291e-17,
#   3.582181366684089e-19,
#   1.2457818253884236e-19,
#   3.0232065106636376e-14,
#   1.996792498504664e-21,
#   8.909684546135176e-16,
#   1.7139857330058052e-15,
#   2.157706992478552e-17,
#   1.1743546391750475e-13,
#   3.1787722110793575e-12,
#   1.4735851931441056e-11,
#   2.0188621389330195e-24,
#   9.707812425683386e-12,
#   8.511880732292973e-16,
#   1.0474450962874237e-18,
#   1.1397345384432508e-22,
#   1.7221673817870728e-13,
#   5.4252280294186004e-15,
#   3.567613755992013e-17,
#   1.1483000921407206e-14,
#   3.405517534921465e-24,
#   1.4842017889318219e-19,
#   2.9291660588956307e-19,
#   4.401099154616655e-19,
#   7.488126415069127e-16,
#   9.316298706159292e-26,
#   5.793219210207693e-11,
#   4.284566373067706e-22,
#   3.9921119084142194e-13,
#   1.0940293970495064e-11,
#   5.66653567701392e-26,
#   2.491523398603254e-16,
#   3.7749735022089314e-16,
#   1.5796619090157108e-23,
#   7.942595004441354e-18,
#   9.331876056471941e-23,
#   1.7375105966097072e-12,
#   1.4285080353695205e-10,
#   2.23327042923161e-22,
#   7.622646786814179e-12,
#   1.1443023246027867e-25,
#   9.687842073733571e-21,
#   1.0055922112015308e-15,
#   3.201454617917616e-16,
#   2.551436340071279e-16,
#   1.547376953690447e-14,
#   1.9927165161194757e-19,
#   1.2149058780155477e-17,
#   3.090652082062456e-18,
#   1.1446620011535593e-16,
#   1.705617833617619e-20,
#   8.501138817478798e-20,
#   1.0029200200429928e-21,
#   5.172082803079965e-20,
#   1.5475281356834943e-16]}
